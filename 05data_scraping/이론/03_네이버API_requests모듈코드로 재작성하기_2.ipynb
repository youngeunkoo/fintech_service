# %%
import requests

# %% [markdown]
# # 1. requests 모듈 : HTTP 프로토콜을 사용할 수 있게 해주는 라이브러리
#
# 웹 페이지와 쉽게 상호작용할 수 있게 해주는 HTTP 라이브러리 <br><br>
#
# requests 모듈 사용 설명서 : https://requests.readthedocs.io/en/latest/

# %% [markdown]
# # 2. requests 모듈 설치
#
# * conda install requests
# * pip install requests

# %% [markdown]
# # 3. requests 모듈 사용서
#
# #### 1) 모듈 불러오기 : import requests
# #### 2) HTTP 접근 요청 get, post
# * r = requests.get(URL, parameters)
# * r = requests.post(URL, data = {key : value}
#
# #### 3) URL 파라미터
# * params = {파라미터1 : value, 파라미터2 : value, 파라미터3 : value}
# * payload = {'key1' : 'value1', 'key2' : 'value2'}
# * r = requests.get(URL, params = payload)

# %% [markdown]
# #### 4) 만들어진 URL 확인 : print(r.url)
# #### 5) header 값 넣기 :
# * r = requests.head(user-agent값)
# * headers = {'key' : 'value1', 'key2' : 'value2
# * r = requests.get(URL, params = payload, headers = headers)
#
# #### 6) 응답요소 response content : r.text, r.json()
# * response = r.text
# * response = r.json()
# #### 7) 응답코드 r.status_code

# %% [markdown]
# r = requests.get('https://api.github.com/user', auth=('user', 'pass'))
# r.status_code
# 200
# r.headers['content-type']
# 'application/json; charset=utf8'
# r.encoding
# 'utf-8'
# r.text
# '{"type":"User"...'
# r.json()
# {'private_gists': 419, 'total_private_repos': 77, ...}

# %% [markdown]
# # =========================================================

# %% [markdown]
# ## * 네이버 검색 API 코드를 urllib 에서 requests로 변경하기

# %%
# 원본 코드
# 네이버 검색 API 예제 - 블로그 검색

import os
import sys
import urllib.request

client_id = "YOUR_CLIENT_ID"
client_secret = "YOUR_CLIENT_SECRET"
encText = urllib.parse.quote("검색할 단어")

url = "https://openapi.naver.com/v1/search/blog?query=" + encText # JSON 결과
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # XML 결과

request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()

if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)

# %%
import requests
import pandas as pd

# %%
# requests 사용하기

url = "https://openapi.naver.com/v1/search/blog"

payload = {'query' : '핀테크', 'display' : 10, 'start' : 1, 'sort' : 'sim'}
headers = {'X-Naver-Client-Id' : "k5K8PLgTE8lcRewiN6sA", 'X-Naver-Client-Secret' : "0i0fiO7U_D"}

r = requests.get(url, params = payload, headers = headers)

print(r.url)

if(r.status_code == 200):
    data = r.json() 
    print(type(data))
else:
    print("Error Code:" + r.status_code)
# Out:
# https://openapi.naver.com/v1/search/blog?query=%ED%95%80%ED%85%8C%ED%81%AC&display=10&start=1&sort=sim
# <class 'dict'>

# %%
df = pd.json_normalize(data['items'])
df
# Out:
#                                             title  \
# 0       서울시, <b>핀테크</b>, 가계대출, 신한은행, 대출 금리 인상...
# 1                   달러스왑 <b>핀테크</b>만으로 800% 수익 난다
# 2          목돈 만들기 앱테크 : 소셜 <b>핀테크</b> 아임인 시작해 볼까?
# 3     손대식, &lt;달러스왑 <b>핀테크</b>만으로 800% 수익 난다!&gt;
# 4  아임인 온라인 계모임 <b>핀테크</b> 플랫폼 feat. 스테이지 채권추심...
# 5   WISE 영국 <b>핀테크</b> 송금 앱 - 싱가포르에서 한국 계좌로 송금 후기
# 6             달러스왑 <b>핀테크</b>만으로 800% 수익 난다 북 리뷰!
# 7   투자의 새로운 시각 '달러스왑 <b>핀테크</b>만으로 800% 수익 난다...
# 8             쿠팡 정산 올라 <b>핀테크</b> 활용 사업자 선정산하는 방법
# 9               [도서] 달러스왑 <b>핀테크</b>만으로 800%수익난다!
#
#                                                 link  \
# 0       https://blog.naver.com/angeldia/223521411021
# 1         https://blog.naver.com/balmin/223520733366
# 2      https://blog.naver.com/jkyun0621/223522303455
# 3      https://blog.naver.com/writeread/223519959546
# 4  https://blog.naver.com/disneyworld777/22350373...
# 5     https://blog.naver.com/gahyun9898/223522337531
# ...

# %%
import requests
import pandas as pd
import time
import os
from dotenv import load_dotenv

# %%
print(os.getcwd())
# Out:
# C:\Users\5-05\Desktop\fintech_service\05data_scraping

# %%
# 함수로 만들었던 서비스 검색 --> requests 로 다시 만들기


def naver_search():
    service = input('''검색 서비스 번호를 입력하세요: 
    1 블로그
    2 책
    3 뉴스
    4 전문자료 
    ''')
    query = input("검색어를 입력하세요: ")
     
    if service == '1':
        service = 'blog'
    elif service == '2':
        service = 'book'
    elif service == '3':
        service = 'news'
    elif service == '4':
        service = 'doc'
        
    book_lists = []
    page = 1
    start = 1
    
    while True:
    

        url =f"https://openapi.naver.com/v1/search/{service}.json"
        payload = {'query' : '핀테크', 'display' : 10, 'start' : 1, 'sort' : 'sim'}
        payload = dict(query = query ,display=10 ,start= start, sort = sort)
        headers = {'X-Naver-Client-Id' : "k5K8PLgTE8lcRewiN6sA", 'X-Naver-Client-Secret' : "0i0fiO7U_D"}

       
            
        try: 
            r = requests.get(url, params = payload, headers = headers)
            
            print(r.url)
            
            if(r.status_code == 200):
                data = r.json() 
                print(type(data))
                book_lists.append(json.loads(response_body.decode('utf-8'))) 
                total_pages = data['total'] // 10 + 1

            else:
                print("Error Code:" + r.status_code)
                break
            
            

            if page < total_pages : 
                page += 1
                if start != 991:
                    start += 10
                elif start == 991:
                    start += 9
                print(f"{page:03d}/{total_pages} 추출중", end= "\r")

            else:
                break



            time.sleep(0.3)   
        except Exception as e:
            print(e)
            break

# %% [markdown]
# ### 위에 아이디, 비번 노출되어 있는데 보안 문제 해결하기 위해선?

# %% [markdown]
# dotenv.

# %% [markdown]
# conda install python-dotenv
# <br> 라고 프롬프트에 입력 후 다운받음.

# %%
# 함수로 만들었던 서비스 검색 --> requests 로 다시 만들기



# .env 파일에서 환경 변수 로드 
load_dotenv()

def naver_search():
    service = input('''검색 서비스 번호를 입력하세요: 
    1 블로그
    2 책
    3 뉴스
    4 전문자료 
    ''')
    query = input("검색어를 입력하세요: ")
     
    if service == '1':
        service = 'blog'
    elif service == '2':
        service = 'book'
    elif service == '3':
        service = 'news'
    elif service == '4':
        service = 'doc'
        
    book_lists = []
    page = 1
    start = 1
    
    while True:
    
        # 아이디, 비번 노출시키지 않는 방법!
        url =f"https://openapi.naver.com/v1/search/{service}.json"
        client_id = os.getenv('client_id') # 네이버 api에 접속 가능한 id
        client_secret = os.getenv('client_secret')     # 네이버 api에 접속 가능한 pw
        payload = dict(query = query ,display=10 ,start= start, sort = sort)
        headers = {'X-Naver-Client-Id' : client_id, 'X-Naver-Client-Secret' : client_secret}
       
            
        try: 
            r = requests.get(url, params = payload, headers = headers)
            
            print(r.url)
            
            if(r.status_code == 200):
                data = r.json() 
                print(type(data))
                book_lists.append(json.loads(response_body.decode('utf-8'))) 
                total_pages = data['total'] // 10 + 1

            else:
                print("Error Code:" + r.status_code)
                break
            
            

            if page < total_pages : 
                page += 1
                if start != 991:
                    start += 10
                elif start == 991:
                    start += 9
                print(f"{page:03d}/{total_pages} 추출중", end= "\r")

            else:
                break



            time.sleep(0.3)   
        except Exception as e:
            print(e)
            break

# %% [markdown]
# # 예제 1 : naver 도서
#
# * 출처 : 네이버 데이터 개발자 센터

# %%
# 네이버 검색 API 예제 - 블로그 검색

import os
import sys
import urllib.request # 파이썬으로 외부에 접속할 수 있게 하는 것

# %% [markdown]
# < get 방식으로 요청 >  <br><br>
#
# 원본 : https://search.shopping.naver.com/book/search?bookTabType=ALL&pageIndex=1&pageSize=40&query=%ED%95%80%ED%85%8C%ED%81%AC&sort=REL   <br><br>
#
#
# URL, endpoint : https://search.shopping.naver.com/book/search  <br><br>
#
#
# parameter : ?bookTabType=ALL&pageIndex=1&pageSize=40&query=%ED%95%80%ED%85%8C%ED%81%AC&sort=REL <br><br>
#
#
# parameter : ? <br>
# bookTabType=ALL  <br>
# &pageIndex=1  <br>
# &pageSize=40&   <br><br>
#
# query=%ED%95%80%ED%85%8C%ED%81%AC&  ===> 검색어 '핀테크' <br><br>
#
# sort=REL   ===> 관련 있는 순서대로

# %% [markdown]
# < post 방식 >

# %%
# 네이버 검색 API 예제 - 블로그 검색

# 네이버개발자센터에서 부여받은 로그인 번호 
client_id = "k5K8PLgTE8lcRewiN6sA"  # 네이버 api에 접속 가능한 id
client_secret = "0i0fiO7U_D"       # 네이버 api에 접속 가능한 pw

encText = urllib.parse.quote("핀테크")



# https://openapi.naver.com/v1/search/book.json
url = "https://openapi.naver.com/v1/search/book.json?query=" + encText # JSON 결과
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # XML 결과
# ? 뒤에 query 말고 display 등 넣을 수 있다. 
# ? 앞에까지가 url 다. 


request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# {
# 	"lastBuildDate":"Mon, 22 Jul 2024 12:33:56 +0900",
# 	"total":99,
# 	"start":1,
# 	"display":10,
# 	"items":[
# 		{
# 			"title":"핀테크",
# 			"link":"https:\/\/search.shopping.naver.com\/book\/catalog\/32438306822",
# 			"image":"https:\/\/shopping-phinf.pstatic.net\/main_3243830\/32438306822.20230920073135.jpg",
# 			"author":"한석주",
# 			"discount":"11400",
# 			"publisher":"커뮤니케이션북스",
# 			"pubdate":"20151101",
# 			"isbn":"9791130441436",
# 			"description":"디지털 기술의 발달은 금융의 모든 것을 바꾸고 있다. 기술 기반의 스타트업들과 비금융권 기업들이 금융 시장에 진입하며 은행을 해체하고 대체해 가는 시대가 오고 있다. 핀테크의 핵심은 기술을 통해 기존의 금융 기관이 제공하지 못했던 부분을 채워 주고, 편의성 증대, 비용 절감, 리스크 분산, 기대 수익 증가 등 고객에게 새로운 가치를 주는 데 있다. 특히 고객들이 쌓은 데이터를 분석해 틈새를 찾아내고 새로운 시장으로 만드는 것이 중요하다. 이 책은 핀테크의 의미와 지급 결제, 대출, 자산관리, 가상 화폐 등 다양한 분야별 성공 사례와 시사점, 오프라인 기업의 대응, 그리고 각국의 핀테크 산업 육성 정책에 대해 살펴본다."
# 		},
# 		{
# 			"title":"핀테크 (IT와 금융이 만나는 새로운 세상)",
# 			"link":"https:\/\/search.shopping.naver.com\/book\/catalog\/32506472036",
# ...

# %%
response_body.decode('utf-8')
# Out:
# '{\n\t"lastBuildDate":"Mon, 22 Jul 2024 12:33:56 +0900",\n\t"total":99,\n\t"start":1,\n\t"display":10,\n\t"items":[\n\t\t{\n\t\t\t"title":"핀테크",\n\t\t\t"link":"https:\\/\\/search.shopping.naver.com\\/book\\/catalog\\/32438306822",\n\t\t\t"image":"https:\\/\\/shopping-phinf.pstatic.net\\/main_3243830\\/32438306822.20230920073135.jpg",\n\t\t\t"author":"한석주",\n\t\t\t"discount":"11400",\n\t\t\t"publisher":"커뮤니케이션북스",\n\t\t\t"pubdate":"20151101",\n\t\t\t"isbn":"9791130441436",\n\t\t\t"description":"디지털 기술의 발달은 금융의 모든 것을 바꾸고 있다. 기술 기반의 스타트업들과 비금융권 기업들이 금융 시장에 진입하며 은행을 해체하고 대체해 가는 시대가 오고 있다. 핀테크의 핵심은 기술을 통해 기존의 금융 기관이 제공하지 못했던 부분을 채워 주고, 편의성 증대, 비용 절감, 리스크 분산, 기대 수익 증가 등 고객에게 새로운 가치를 주는 데 있다. 특히 고객들이 쌓은 데이터를 분석해 틈새를 찾아내고 새로운 시장으로 만드는 것이 중요하다. 이 책은 핀테크의 의미와 지급 결제, 대출, 자산관리, 가상 화폐 등 다양한 분야별 성공 사례와 시사점, 오프라인 기업의 대응, 그리고 각국의 핀테크 산업 육성 정책에 대해 살펴본다."\n\t\t},\n\t\t{\n\t\t\t"title":"핀테크 (IT와 금융이 만나는 새로운 세상)",\n\t\t\t"link":"https:\\/\\/search.shopping.naver.com\\/book\\/catalog\\/32506472036",\n\t\
# ...

# %%
print(type(response_body.decode('utf-8')))
# Out:
# <class 'str'>

# %%
import json

# %%
data = json.loads(response_body.decode('utf-8'))

# %%
print(type(data))
# Out:
# <class 'dict'>

# %% [markdown]
# url = "https://www.yes24.com/Product/Category/BestSeller?categoryNumber=001&pageNumber={page_number}&pageSize=120"

# %%
# 네이버 검색 API 예제 - 블로그 검색 : 원본 오리지날

# 네이버개발자센터에서 부여받은 로그인 번호 
client_id = "k5K8PLgTE8lcRewiN6sA"  # 네이버 api에 접속 가능한 id
client_secret = "0i0fiO7U_D"       # 네이버 api에 접속 가능한 pw

encText = urllib.parse.quote("핀테크")

print(encText)

# https://openapi.naver.com/v1/search/book.json
url = f"https://openapi.naver.com/v1/search/book.json?query={encText}&display=10&start={1}" # JSON 결과
print("url: " , url)
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # XML 결과
# ? 뒤에 query 말고 display 등 넣을 수 있다. 
# ? 앞에까지가 url 다. 


request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# %ED%95%80%ED%85%8C%ED%81%AC
# url:  https://openapi.naver.com/v1/search/book.json?query=%ED%95%80%ED%85%8C%ED%81%AC&display=10&start=1
# {
# 	"lastBuildDate":"Mon, 22 Jul 2024 15:21:28 +0900",
# 	"total":99,
# 	"start":1,
# 	"display":10,
# 	"items":[
# 		{
# 			"title":"핀테크",
# 			"link":"https:\/\/search.shopping.naver.com\/book\/catalog\/32438306822",
# 			"image":"https:\/\/shopping-phinf.pstatic.net\/main_3243830\/32438306822.20230920073135.jpg",
# 			"author":"한석주",
# 			"discount":"11400",
# 			"publisher":"커뮤니케이션북스",
# 			"pubdate":"20151101",
# 			"isbn":"9791130441436",
# 			"description":"디지털 기술의 발달은 금융의 모든 것을 바꾸고 있다. 기술 기반의 스타트업들과 비금융권 기업들이 금융 시장에 진입하며 은행을 해체하고 대체해 가는 시대가 오고 있다. 핀테크의 핵심은 기술을 통해 기존의 금융 기관이 제공하지 못했던 부분을 채워 주고, 편의성 증대, 비용 절감, 리스크 분산, 기대 수익 증가 등 고객에게 새로운 가치를 주는 데 있다. 특히 고객들이 쌓은 데이터를 분석해 틈새를 찾아내고 새로운 시장으로 만드는 것이 중요하다. 이 책은 핀테크의 의미와 지급 결제, 대출, 자산관리, 가상 화폐 등 다양한 분야별 성공 사례와 시사점, 오프라인 기업의 대응, 그리고 각국의 핀테크 산업 육성 정책에 대해 살펴본다."
# 		},
# 		{
# ...

# %%
import json
import pandas as pd

# %% [markdown]
# # 총 99개의 결과가 있으므로 10페이지 가져오는 코드 작성

# %%
for start in range(1, 100, 10): 
    print(start)
# Out:
# 1
# 11
# 21
# 31
# 41
# 51
# 61
# 71
# 81
# 91

# %% [markdown]
# * display : 한 페이지에 몇개 불러오는지
# 한 번에 표시할 검색 결과 개수(기본값: 10, 최댓값: 100) <br>
#
# * start : 검색 시작 위치(기본값: 1, 최댓값: 1000)

# %%
book_lists = []

for start in range(1, 100, 10):   # 총 10 페이지
    client_id = "k5K8PLgTE8lcRewiN6sA"  # 네이버 api에 접속 가능한 id
    client_secret = "0i0fiO7U_D"       # 네이버 api에 접속 가능한 pw

    encText = urllib.parse.quote("핀테크")

    print(encText)
    url = f"https://openapi.naver.com/v1/search/book.json?query={encText}&display=10&start={start}" # JSON 결과
    print("url: " , url)

    request = urllib.request.Request(url)
    request.add_header("X-Naver-Client-Id",client_id)
    request.add_header("X-Naver-Client-Secret",client_secret)
    response = urllib.request.urlopen(request)
    rescode = response.getcode()
    if(rescode==200):
        response_body = response.read()
        data = json.loads(response_body.decode('utf-8'))
        book_lists.append(json.loads(response_body.decode('utf-8'))) # book_lists 리스트에 넣기
    
    else:
        print("Error Code:" + rescode)
# Out:
# %ED%95%80%ED%85%8C%ED%81%AC
# url:  https://openapi.naver.com/v1/search/book.json?query=%ED%95%80%ED%85%8C%ED%81%AC&display=10&start=1
# %ED%95%80%ED%85%8C%ED%81%AC
# url:  https://openapi.naver.com/v1/search/book.json?query=%ED%95%80%ED%85%8C%ED%81%AC&display=10&start=11
# %ED%95%80%ED%85%8C%ED%81%AC
# url:  https://openapi.naver.com/v1/search/book.json?query=%ED%95%80%ED%85%8C%ED%81%AC&display=10&start=21
# %ED%95%80%ED%85%8C%ED%81%AC
# url:  https://openapi.naver.com/v1/search/book.json?query=%ED%95%80%ED%85%8C%ED%81%AC&display=10&start=31
# %ED%95%80%ED%85%8C%ED%81%AC
# url:  https://openapi.naver.com/v1/search/book.json?query=%ED%95%80%ED%85%8C%ED%81%AC&display=10&start=41
# %ED%95%80%ED%85%8C%ED%81%AC
# url:  https://openapi.naver.com/v1/search/book.json?query=%ED%95%80%ED%85%8C%ED%81%AC&display=10&start=51
# %ED%95%80%ED%85%8C%ED%81%AC
# url:  https://openapi.naver.com/v1/search/book.json?query=%ED%95%80%ED%85%8C%ED%81%AC&display=10&start=61
# %ED%95%80%ED%85%8C%ED%81%AC
# ...

# %%
book_lists[0]
# Out:
# {'lastBuildDate': 'Mon, 22 Jul 2024 14:21:36 +0900',
#  'total': 99,
#  'start': 1,
#  'display': 10,
#  'items': [{'title': '핀테크',
#    'link': 'https://search.shopping.naver.com/book/catalog/32438306822',
#    'image': 'https://shopping-phinf.pstatic.net/main_3243830/32438306822.20230920073135.jpg',
#    'author': '한석주',
#    'discount': '11400',
#    'publisher': '커뮤니케이션북스',
#    'pubdate': '20151101',
#    'isbn': '9791130441436',
#    'description': '디지털 기술의 발달은 금융의 모든 것을 바꾸고 있다. 기술 기반의 스타트업들과 비금융권 기업들이 금융 시장에 진입하며 은행을 해체하고 대체해 가는 시대가 오고 있다. 핀테크의 핵심은 기술을 통해 기존의 금융 기관이 제공하지 못했던 부분을 채워 주고, 편의성 증대, 비용 절감, 리스크 분산, 기대 수익 증가 등 고객에게 새로운 가치를 주는 데 있다. 특히 고객들이 쌓은 데이터를 분석해 틈새를 찾아내고 새로운 시장으로 만드는 것이 중요하다. 이 책은 핀테크의 의미와 지급 결제, 대출, 자산관리, 가상 화폐 등 다양한 분야별 성공 사례와 시사점, 오프라인 기업의 대응, 그리고 각국의 핀테크 산업 육성 정책에 대해 살펴본다.'},
#   {'title': '핀테크 (IT와 금융이 만나는 새로운 세상)',
#    'link': 'https://search.shopping.naver.com/book/catalog/32506472036',
# ...

# %%
book_lists[1]
# Out:
# {'lastBuildDate': 'Mon, 22 Jul 2024 14:22:24 +0900',
#  'total': 99,
#  'start': 11,
#  'display': 10,
#  'items': [{'title': '핀테크 보안경영 (보안사령부를 구축하라)',
#    'link': 'https://search.shopping.naver.com/book/catalog/32492053731',
#    'image': 'https://shopping-phinf.pstatic.net/main_3249205/32492053731.20221019145226.jpg',
#    'author': '김려성',
#    'discount': '30600',
#    'publisher': '진한엠앤비',
#    'pubdate': '20160420',
#    'isbn': '9791170094371',
#    'description': '핀테크 보안은 금융거래의 신뢰성을 유지하면서 금융과 IT 융합에 의해 편의성과 다양성을 지원할 수 있어야 한다. 사용자측면의 사전 보안에서 서버측면의 사후 보안으로 보안 프레임워크가 변화되고 있다. 그래서 다양한 인증기술의 수용, 기술의 중립성 구현, 사용자의 보안의식 강화 등의 구체적 목적을 가지고 추진되어야 한다. 핀테크 서비스를 제공하는 기업은 보안대책을 수립함에 있어 핀테크 관련 보 안정책에 대한 명확한 이해를 바탕으로 종합적인 핀테크 서비스 안전성 확보방안을 수립해야 하겠다.'},
#   {'title': '핀테크 4.0 (핀테크 혁명과 금융의 미래)',
#    'link': 'https://search.shopping.naver.com/book/catalog/32454456445',
#    'image': 'https://shopping-phinf.pstatic.net/main_3245445/32454456445.20220527025312.jpg',
#    'author': '김종현',
# ...

# %%
book_lists[2]
# Out:
# {'lastBuildDate': 'Mon, 22 Jul 2024 14:21:37 +0900',
#  'total': 99,
#  'start': 21,
#  'display': 10,
#  'items': [{'title': '진짜 핀테크 이야기 (한 발 앞서 정복하는)',
#    'link': 'https://search.shopping.naver.com/book/catalog/32492630762',
#    'image': 'https://shopping-phinf.pstatic.net/main_3249263/32492630762.20221228073118.jpg',
#    'author': '목승환',
#    'discount': '13500',
#    'publisher': '한즈미디어(한스미디어)',
#    'pubdate': '20150924',
#    'isbn': '9788959758586',
# ...

# %%
import json
import pandas as pd

# %%
df = pd.json_normalize(book_lists[0]['items'])
df
# Out:
#                                         title  \
# 0                                         핀테크
# 1                    핀테크 (IT와 금융이 만나는 새로운 세상)
# 2  핀테크 전쟁 (세계 금융 시장의 거대한 트렌드 | 새로운 돈의 시대가 온다)
# 3                    핀테크 4.0 (핀테크 혁명과 금융의 미래)
# 4   핀테크 혁명 (모바일 은행 설립자가 알려주는 핀테크 시대의 돈 관리 기술)
# 5            핀테크가 강한 나라 (석학 9인의 금융 플랫폼 미래 통찰)
# 6                                핀테크와 법 (제3판)
# 7          내일의 핀테크 (금융대혁명의 시대, 어떻게 살아남을 것인가?)
# 8                     차이나 핀테크 (중국에선 현금이 필요없다)
# 9       핀테크 시대 (기술변화와 함께 다가오는 법과 규제 패러다임의 변화)
#
#                                                 link  \
# 0  https://search.shopping.naver.com/book/catalog...
# 1  https://search.shopping.naver.com/book/catalog...
# 2  https://search.shopping.naver.com/book/catalog...
# 3  https://search.shopping.naver.com/book/catalog...
# 4  https://search.shopping.naver.com/book/catalog...
# 5  https://search.shopping.naver.com/book/catalog...
# 6  https://search.shopping.naver.com/book/catalog...
# ...

# %%
result = pd.DataFrame()

for book_list in book_lists[:]: 
    temp = pd.json_normalize(book_list['items'])
    result = pd.concat([result, temp])
    
result
result.to_csv("naver_book_api_fintech_result.csv", encoding = "cp949")
# 엑셀로 저장되는 것 
print(result)
# Out:
#                                                 title  \
# 0                                                 핀테크
# 1                            핀테크 (IT와 금융이 만나는 새로운 세상)
# 2          핀테크 전쟁 (세계 금융 시장의 거대한 트렌드 | 새로운 돈의 시대가 온다)
# 3                            핀테크 4.0 (핀테크 혁명과 금융의 미래)
# 4           핀테크 혁명 (모바일 은행 설립자가 알려주는 핀테크 시대의 돈 관리 기술)
# ..                                                ...
# 4   4차산업 기업·스타트업 주소록(2024)(CD) (3D프린터, IOT, VR, 가상...
# 5   전국 체험마을 주소록(2024)(CD) (3D프린터, IOT, VR, 가상현실, 드...
# 6     IoT기반 근거리 무선통신/핀테크 산업 현황과 무선전력전송 및 무선충전 기술개발 동향
# 7   핀테크 / 블록체인 기술이 적용된 온라인 시스템 전자결제 / 보안 / 인증 시장 전...
# 8   [CD] 2018 4차산업 기업.스타트업 주소록 - CD-ROM 1장 (가상현실·드...
#
#                                                  link  \
# 0   https://search.shopping.naver.com/book/catalog...
# 1   https://search.shopping.naver.com/book/catalog...
# 2   https://search.shopping.naver.com/book/catalog...
# 3   https://search.shopping.naver.com/book/catalog...
# ...

# %% [markdown]
# ### 이 문제는 "핀테크"로 도서를 검색했을 때, 99개가 나오는 것을 확인 후 짠 코드이기 때문에, 다른 도서를 검색했을 때 적용하기 힘들다. while문으로 모든 도서 검색에 적용될 수 있도록 무한반복되게 짜야함.

# %%
import time

# %%
book_lists = []
page = 1
start = 1 

# for start in range(1, 100, 10):   # 총 10 페이지
while True:
    
    client_id = "k5K8PLgTE8lcRewiN6sA"  # 네이버 api에 접속 가능한 id
    client_secret = "0i0fiO7U_D"       # 네이버 api에 접속 가능한 pw

    encText = urllib.parse.quote("핀테크")  #  여기 안에 단어를 바꿀 때

    print(encText)
    url = f"https://openapi.naver.com/v1/search/book.json?query={encText}&display=10&start={start}" # JSON 결과
    print("url: " , url)

    request = urllib.request.Request(url)
    request.add_header("X-Naver-Client-Id",client_id)
    request.add_header("X-Naver-Client-Secret",client_secret)
    response = urllib.request.urlopen(request)
    rescode = response.getcode()
    if(rescode==200):
        response_body = response.read()
        data = json.loads(response_body.decode('utf-8'))
        book_lists.append(json.loads(response_body.decode('utf-8'))) # book_lists 리스트에 넣기
    else:
        print("Error Code:" + rescode)
#     page > total_pages = data['totol'] // 10 + 1
#     total_pages 선언해주지 않아서 생기는 오류?
    if page < total_pages : 
        page += 1
        start += 10
    else : 
        total = data['total']
        total_pages = (total // 10) + 1
        break
    
    time.sleep(1)
# Out:
# %ED%95%80%ED%85%8C%ED%81%AC
# url:  https://openapi.naver.com/v1/search/book.json?query=%ED%95%80%ED%85%8C%ED%81%AC&display=10&start=1
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[90], line 29
#      27         print("Error Code:" + rescode)
#      28 #     page > total_pages = data['totol'] // 10 + 1
# ---> 29     if page < total_pages :
#      30         page += 1
#      31         start += 10
#
# NameError: name 'total_pages' is not defined

# %%
# 내 답안 


book_lists = []
page = 1
start = 1 


while True:
    
    client_id = "k5K8PLgTE8lcRewiN6sA"  # 네이버 api에 접속 가능한 id
    client_secret = "0i0fiO7U_D"       # 네이버 api에 접속 가능한 pw

    encText = urllib.parse.quote("핀테크")  #  여기 안에 단어를 바꿀 때

    print(encText)
    url = f"https://openapi.naver.com/v1/search/book.json?query={encText}&display=10&start={start}" # JSON 결과
    print("url: " , url)

    request = urllib.request.Request(url)
    request.add_header("X-Naver-Client-Id",client_id)
    request.add_header("X-Naver-Client-Secret",client_secret)
    response = urllib.request.urlopen(request)
    rescode = response.getcode()
    
    if(rescode==200):
        response_body = response.read()
        data = json.loads(response_body.decode('utf-8'))
        book_lists.append(json.loads(response_body.decode('utf-8'))) # book_lists 리스트에 넣기
        total_pages = data['total'] // 10 + 1
    else:
        print("Error Code:" + rescode)

    if page < total_pages : 
        page += 1
        start += 10
    else: 
        total = data['total']
        total_pages = (total // 10) + 1
        break
    
    time.sleep(1)
# Out:
# %ED%95%80%ED%85%8C%ED%81%AC
# url:  https://openapi.naver.com/v1/search/book.json?query=%ED%95%80%ED%85%8C%ED%81%AC&display=10&start=1
# %ED%95%80%ED%85%8C%ED%81%AC
# url:  https://openapi.naver.com/v1/search/book.json?query=%ED%95%80%ED%85%8C%ED%81%AC&display=10&start=11
# %ED%95%80%ED%85%8C%ED%81%AC
# url:  https://openapi.naver.com/v1/search/book.json?query=%ED%95%80%ED%85%8C%ED%81%AC&display=10&start=21
# %ED%95%80%ED%85%8C%ED%81%AC
# url:  https://openapi.naver.com/v1/search/book.json?query=%ED%95%80%ED%85%8C%ED%81%AC&display=10&start=31
# %ED%95%80%ED%85%8C%ED%81%AC
# url:  https://openapi.naver.com/v1/search/book.json?query=%ED%95%80%ED%85%8C%ED%81%AC&display=10&start=41
# %ED%95%80%ED%85%8C%ED%81%AC
# url:  https://openapi.naver.com/v1/search/book.json?query=%ED%95%80%ED%85%8C%ED%81%AC&display=10&start=51
# %ED%95%80%ED%85%8C%ED%81%AC
# url:  https://openapi.naver.com/v1/search/book.json?query=%ED%95%80%ED%85%8C%ED%81%AC&display=10&start=61
# %ED%95%80%ED%85%8C%ED%81%AC
# ...

# %%
data['total'] // 10 + 1
# Out:
# 10

# %%
# final 답안 (강사님 답안)

book_lists = []
page = 1
start = 1 


while True:
    
    client_id = "k5K8PLgTE8lcRewiN6sA"  # 네이버 api에 접속 가능한 id
    client_secret = "0i0fiO7U_D"       # 네이버 api에 접속 가능한 pw

    encText = urllib.parse.quote("파이썬")  #  여기 안에 단어를 바꿀 때

    print(encText)
    url = f"https://openapi.naver.com/v1/search/book.json?query={encText}&display=10&start={start}" # JSON 결과
    print("url: " , url, end= "\r")

    request = urllib.request.Request(url)
    request.add_header("X-Naver-Client-Id",client_id)
    request.add_header("X-Naver-Client-Secret",client_secret)
    response = urllib.request.urlopen(request)
    rescode = response.getcode()
    
    if(rescode==200):
        response_body = response.read()
        data = json.loads(response_body.decode('utf-8'))
        book_lists.append(json.loads(response_body.decode('utf-8'))) # book_lists 리스트에 넣기
        total_pages = data['total'] // 10 + 1
        
    else:
        print("Error Code:" + rescode)
        break
    
    if page < total_pages : 
        page += 1
        start += 10
        print(f"{page:03d}/{total_pages} 추출중", end= "\r")
    
    else:
        break
    
   
    
    time.sleep(0.5)  # 0.5 초 단위로 결과값을 출력함.
# Out:
# %ED%95%80%ED%85%8C%ED%81%AC
# %ED%95%80%ED%85%8C%ED%81%AC.com/v1/search/book.json?query=%ED%95%80%ED%85%8C%ED%81%AC&display=10&start=1
# %ED%95%80%ED%85%8C%ED%81%AC.com/v1/search/book.json?query=%ED%95%80%ED%85%8C%ED%81%AC&display=10&start=11
# %ED%95%80%ED%85%8C%ED%81%AC.com/v1/search/book.json?query=%ED%95%80%ED%85%8C%ED%81%AC&display=10&start=21
# %ED%95%80%ED%85%8C%ED%81%AC.com/v1/search/book.json?query=%ED%95%80%ED%85%8C%ED%81%AC&display=10&start=31
# %ED%95%80%ED%85%8C%ED%81%AC.com/v1/search/book.json?query=%ED%95%80%ED%85%8C%ED%81%AC&display=10&start=41
# %ED%95%80%ED%85%8C%ED%81%AC.com/v1/search/book.json?query=%ED%95%80%ED%85%8C%ED%81%AC&display=10&start=51
# %ED%95%80%ED%85%8C%ED%81%AC.com/v1/search/book.json?query=%ED%95%80%ED%85%8C%ED%81%AC&display=10&start=61
# %ED%95%80%ED%85%8C%ED%81%AC.com/v1/search/book.json?query=%ED%95%80%ED%85%8C%ED%81%AC&display=10&start=71
# ...

# %%
result = pd.DataFrame()

for book_list in book_lists[:]: 
    temp = pd.json_normalize(book_list['items'])
    result = pd.concat([result, temp])
    
result
result.to_csv("naver_book_api_fintech_result2.csv", encoding = "cp949")
# 엑셀로 저장되는 것

# %%
# final 답안 (강사님 답안)

book_lists = []
page = 1
start = 1 
query = input("검색어를 입력하세요: ")

while True:
    
    client_id = "k5K8PLgTE8lcRewiN6sA"  # 네이버 api에 접속 가능한 id
    client_secret = "0i0fiO7U_D"       # 네이버 api에 접속 가능한 pw

    encText = urllib.parse.quote(query)  #  여기 안에 단어를 바꿀 때

    print(encText)
    url = f"https://openapi.naver.com/v1/search/book.json?query={encText}&display=10&start={start}" # JSON 결과
    print("url: " , url, end= "\r")
    
    try: 
        request = urllib.request.Request(url)
        request.add_header("X-Naver-Client-Id",client_id)
        request.add_header("X-Naver-Client-Secret",client_secret)
        response = urllib.request.urlopen(request)
        rescode = response.getcode()

        if(rescode==200):
            response_body = response.read()
            data = json.loads(response_body.decode('utf-8'))
            book_lists.append(json.loads(response_body.decode('utf-8'))) # book_lists 리스트에 넣기
            total_pages = data['total'] // 10 + 1

        else:
            print("Error Code:" + rescode)
            break

        if page < total_pages : 
            page += 1
            if start != 991:
                start += 10
            elif start == 991:
                start += 9
            print(f"{page:03d}/{total_pages} 추출중", end= "\r")

        else:
            break



        time.sleep(0.3)  # 0.3 초 단위로 결과값을 출력함. 
    except Exception as e:
        print(e)
        break
        
        
        
    
result = pd.DataFrame()

for book_list in book_lists[:]: 
    temp = pd.json_normalize(book_list['items'])
    result = pd.concat([result, temp])
    
result
result.to_csv(f"naver_book_api_fintech_{query}_result.csv", encoding = "cp949") # 안될때는 'utf-8' 로 변경해서 저장?
# 엑셀로 저장되는 것 
# 안될때는 'utf-8' 로 변경해서 저장?
# 하지만 엑셀에서 깨져서 보일 것임.
# Out:
# 검색어를 입력하세요: 아프리카
# %EC%95%84%ED%94%84%EB%A6%AC%EC%B9%B4
# %EC%95%84%ED%94%84%EB%A6%AC%EC%B9%B4earch/book.json?query=%EC%95%84%ED%94%84%EB%A6%AC%EC%B9%B4&display=10&start=1
# %EC%95%84%ED%94%84%EB%A6%AC%EC%B9%B4earch/book.json?query=%EC%95%84%ED%94%84%EB%A6%AC%EC%B9%B4&display=10&start=11
# %EC%95%84%ED%94%84%EB%A6%AC%EC%B9%B4earch/book.json?query=%EC%95%84%ED%94%84%EB%A6%AC%EC%B9%B4&display=10&start=21
# %EC%95%84%ED%94%84%EB%A6%AC%EC%B9%B4earch/book.json?query=%EC%95%84%ED%94%84%EB%A6%AC%EC%B9%B4&display=10&start=31
# %EC%95%84%ED%94%84%EB%A6%AC%EC%B9%B4earch/book.json?query=%EC%95%84%ED%94%84%EB%A6%AC%EC%B9%B4&display=10&start=41
# %EC%95%84%ED%94%84%EB%A6%AC%EC%B9%B4earch/book.json?query=%EC%95%84%ED%94%84%EB%A6%AC%EC%B9%B4&display=10&start=51
# %EC%95%84%ED%94%84%EB%A6%AC%EC%B9%B4earch/book.json?query=%EC%95%84%ED%94%84%EB%A6%AC%EC%B9%B4&display=10&start=61
# %EC%95%84%ED%94%84%EB%A6%AC%EC%B9%B4earch/book.json?query=%EC%95%84%ED%94%84%EB%A6%AC%EC%B9%B4&display=10&start=71
# ...

# %% [markdown]
# # ==============================================

# %% [markdown]
# # 예제 2 : Yes24

# %%
# Yes24

# https://openapi.naver.com/v1/search/book.json
url = "https://www.yes24.com/Product/Category/BestSeller?categoryNumber=001&pageNumber={page_number}&pageSize=120" + encText # JSON 결과
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # XML 결과
# ? 뒤에 query 말고 display 등 넣을 수 있다. 
# ? 앞에까지가 url 다. 


request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# 	<!DOCTYPE html >
# 	<html lang="ko">
#
# <head><link rel="alternate" media="only screen and(max-width: 640px)" href="https://m.yes24.com/Home/Best?DispNo=001"
# 	<meta http-equiv="X-UA-Compatible" content="IE=Edge" />
# 	<meta http-equiv="Content-Type" content="text/html;charset=utf-8" />
# 	<meta http-equiv="Accept-CH" content="dpr, width, viewport-width, rtt, downlink, ect, UA, UA-Platform, UA-Arch, UA-Model, UA-Mobile, UA-Full-Version" />
# 	<meta http-equiv="Accept-CH-Lifetime" content="86400" />
# 	<meta name="referrer" content="unsafe-url" />
# 	<meta name="viewport" content="width=1170" />
#
# 	<title> 국내도서 종합 베스트 - 예스24 </title>
#
# 	<meta name="title" content="예스24" />
# 	<meta name="description" content="YOUR EVERY STORY 문화 콘텐츠 플랫폼, 예스24" />
# 	<meta name="keywords" content="인터넷 서점, 온라인 쇼핑, 상품 추천, 쇼핑몰, 상품 검색, 도서 정보, 국내도서, 외국도서, 전자책, eBook, 이북, 크레마, 공연, 콘서트, 뮤지컬, 음반, 예매, DVD, 블루레이, 예스24, YES24, 교보문고, 알라딘, 리센스, 예스24 도서용품, 친환경 PB 브랜드, 사은품, 굿즈" />
#
#
# ...

# %%
import time

# %%
book_list = []
for page_number in range(1,10):
    print("page_number: ", page_number, end = "\r")
    url = "https://www.yes24.com/Product/Category/BestSeller?categoryNumber=001&pageNumber=1&pageSize=24" + encText # JSON 결과
    # url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # XML 결과
    # ? 뒤에 query 말고 display 등 넣을 수 있다. 
    # ? 앞에까지가 url 다. 


    request = urllib.request.Request(url)
    request.add_header("X-Naver-Client-Id",client_id)
    request.add_header("X-Naver-Client-Secret",client_secret)
    response = urllib.request.urlopen(request)
    rescode = response.getcode()
    if(rescode==200):
        response_body = response.read()
        book_list.append(response_body.decode('utf-8'))
    else:
        print("Error Code:" + rescode)
    time.sleep(5)
# Out:
# page_number:  9

# %%
len(book_list)
# Out:
# 9

# %%
book_list[0]
# Out:
# '\r\n\r\n\r\n\r\n\r\n\t<!DOCTYPE html >\r\n\t<html lang="ko">\r\n\r\n<head><link rel="alternate" media="only screen and(max-width: 640px)" href="https://m.yes24.com/Home/Best?DispNo=001"\r\n\t<meta http-equiv="X-UA-Compatible" content="IE=Edge" />\r\n\t<meta http-equiv="Content-Type" content="text/html;charset=utf-8" />\r\n\t<meta http-equiv="Accept-CH" content="dpr, width, viewport-width, rtt, downlink, ect, UA, UA-Platform, UA-Arch, UA-Model, UA-Mobile, UA-Full-Version" />\r\n\t<meta http-equiv="Accept-CH-Lifetime" content="86400" />\r\n\t<meta name="referrer" content="unsafe-url" />\r\n\t<meta name="viewport" content="width=1170" />\r\n\r\n\t<title> 국내도서 종합 베스트 - 예스24 </title> \r\n\r\n\t<meta name="title" content="예스24" />\r\n\t<meta name="description" content="YOUR EVERY STORY 문화 콘텐츠 플랫폼, 예스24" />\r\n\t<meta name="keywords" content="인터넷 서점, 온라인 쇼핑, 상품 추천, 쇼핑몰, 상품 검색, 도서 정보, 국내도서, 외국도서, 전자책, eBook, 이북, 크레마, 공연, 콘서트, 뮤지컬, 음반, 예매, DVD, 블루레이, 예스24, YES24, 교보문고, 알라딘, 리센스, 예스24 도서용품, 친
# ...

# %% [markdown]
# # 네이버 뉴스 검색하기

# %%
# final 답안 (강사님 답안)

book_lists = []
page = 1
start = 1 
query = input("검색어를 입력하세요: ")

while True:
    
    client_id = "k5K8PLgTE8lcRewiN6sA"  # 네이버 api에 접속 가능한 id
    client_secret = "0i0fiO7U_D"       # 네이버 api에 접속 가능한 pw

    encText = urllib.parse.quote(query)  #  여기 안에 단어를 바꿀 때

#     print(encText)
    url = f"https://openapi.naver.com/v1/search/news.json?query={encText}&display=10&start={start}" # JSON 결과
#     print("url: " , url, end= "\r")
    try: 
        request = urllib.request.Request(url)
        request.add_header("X-Naver-Client-Id",client_id)
        request.add_header("X-Naver-Client-Secret",client_secret)
        response = urllib.request.urlopen(request)
        rescode = response.getcode()

        if(rescode==200):
            response_body = response.read()
            data = json.loads(response_body.decode('utf-8'))
            book_lists.append(json.loads(response_body.decode('utf-8'))) # book_lists 리스트에 넣기
            total_pages = data['total'] // 10 + 1

        else:
            print("Error Code:" + rescode)
            break

        if page < total_pages : 
            page += 1
            if start != 991:
                start += 10
            elif start == 991:
                start += 9
            print(f"{page:03d}/{total_pages} 추출중", end= "\r")

        else:
            break



        time.sleep(0.3)  # 0.3 초 단위로 결과값을 출력함. 
    except Exception as e:
        print(e)
        break
        
        
        
    
result = pd.DataFrame()

for book_list in book_lists[:]: 
    temp = pd.json_normalize(book_list['items'])
    result = pd.concat([result, temp])
    
result
result.to_csv(f"naver_news_api_fintech_{query}_result.csv", encoding = "utf-8") # 안될때는 'utf-8' 로 변경해서 저장?
# 엑셀로 저장되는 것 
# 안될때는 'utf-8' 로 변경해서 저장?
# 하지만 엑셀에서 깨져서 보일 것임.
# Out:
# 검색어를 입력하세요: 페이커티원
# 038/38 추출중

# %% [markdown]
# # 함수 만들기

# %% [markdown]
# 1.서비스 선택 : 블로그 / 책 / 뉴스 / 전문자료 <br>
# 2. 검색어 입력 :  <br>
# 3. 함수화  <br>

# %%
# final 답안 (강사님 답안)


def naver_search():
    service = input('''검색 서비스 번호를 입력하세요: 
    1 블로그
    2 책
    3 뉴스
    4 전문자료 
    ''')
    query = input("검색어를 입력하세요: ")
     
    if service == '1':
        service = 'blog'
    elif service == '2':
        service = 'book'
    elif service == '3':
        service = 'news'
    elif service == '4':
        service = 'doc'
        
    book_lists = []
    page = 1
    start = 1 
    

    while True:

        client_id = "k5K8PLgTE8lcRewiN6sA"  # 네이버 api에 접속 가능한 id
        client_secret = "0i0fiO7U_D"       # 네이버 api에 접속 가능한 pw

        encText = urllib.parse.quote(query)  #  여기 안에 단어를 바꿀 때

    #     print(encText)
        url = f"https://openapi.naver.com/v1/search/{service}.json?query={encText}&display=10&start={start}" # JSON 결과
    #     print("url: " , url, end= "\r")
        try: 
            request = urllib.request.Request(url)
            request.add_header("X-Naver-Client-Id",client_id)
            request.add_header("X-Naver-Client-Secret",client_secret)
            response = urllib.request.urlopen(request)
            rescode = response.getcode()

            if(rescode==200):
                response_body = response.read()
                data = json.loads(response_body.decode('utf-8'))
                book_lists.append(json.loads(response_body.decode('utf-8'))) # book_lists 리스트에 넣기
                total_pages = data['total'] // 10 + 1

            else:
                print("Error Code:" + rescode)
                break

            if page < total_pages : 
                page += 1
                if start != 991:
                    start += 10
                elif start == 991:
                    start += 9
                print(f"{page:03d}/{total_pages} 추출중", end= "\r")

            else:
                break



            time.sleep(0.3)  # 0.3 초 단위로 결과값을 출력함. 
        except Exception as e:
            print(e)
            break




    result = pd.DataFrame()

    for book_list in book_lists[:]: 
        temp = pd.json_normalize(book_list['items'])
        result = pd.concat([result, temp])

    result
    result.to_csv(f"naver_{service}_api_fintech_{query}_result.csv", encoding = "utf-8") # 안될때는 'utf-8' 로 변경해서 저장?
    return

# %%
naver_search()

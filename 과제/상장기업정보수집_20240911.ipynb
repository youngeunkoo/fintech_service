# %%
import time
from datetime import date
import requests
import pandas as pd
from bs4 import BeautifulSoup as bs
from sqlalchemy import create_engine, text

# %% [markdown]
# https://kind.krx.co.kr/corpgeneral/corpList.do?method=searchCorpList&pageIndex=1&currentPageSize=15&comAbbrv=&beginIndex=&orderMode=3&orderStat=D&isurCd=&repIsuSrtCd=&searchCodeType=&marketType=&searchType=13&industry=&fiscalYearEnd=all&comAbbrvTmp=&location=all

# %%
today = date.today()
# print(today, type(today))
today = str(today)
# print(today, type(today))
# Out:
# 2024-09-11 <class 'datetime.date'>

# %%
url = "https://kind.krx.co.kr/corpgeneral/corpList.do"

payload = dict( method="searchCorpList",pageIndex=1,currentPageSize=15, orderMode=3,orderStat="D", searchType=13   )

r = requests.get(url, params = payload)
print(r.status_code)
print(r.text)
# Out:
# 200
#
#
#
#
#
#
#
#
# <section class="scrarea type-00">
# 	<table class="list type-00 tmt30" summary="회사명, 업종, 주요제품, 상장일, 결산월, 대표자명, 홈페이지, 지역">
# 		<caption>목록</caption>
# 		<colgroup>
# 			<col width="*" />
# 			<col width="15%" />
# 			<col width="20%" />
# 			<col width="11%" />
# 			<col width="8%" />
# 			<col width="10%" />
# 			<col width="8%" />
# 			<col width="12%" />
# 		</colgroup>
# 		<thead>
# 			<tr class="first" id="title-contents">
# 			</tr>
# 		</thead>
# 		<tbody>
#
#
#
# 			<tr
# 					class="first"
# 			>
# 				<td class="first" title="미래에셋비전기업인수목적7호 주식회사"><img src='/images/common/icn_t_ko.gif' class='vmiddle legend' alt='코스닥'> <a id="companysum" href="#companysum" onclick="companysummary_open('48268'); return false;" title='미래에셋비전스팩7호'> 미래에셋비전스팩7호</a> </td>
# 				<td class="textOverflow" title="금융 지원 서비스업">금융 지원 서비스업</td>
# 				<td class="textOverflow" title="기업인수합병">기업인수합병</td>
# 				<td class="txc">2024-09-11</td>
# 				<td class="txc">12월</td>
# 				<td class="txc" title="송우영">송우영</td>
# 				<td class="txc">
#
# 				</td>
# 				<td class="txc">서울특별시</td>
# 			</tr>
#
# 			<tr
#
# 			>
# 				<td class="first" title="(주)아이비젼웍스"><img src='/images/common/icn_t_ko.gif' class='vmiddle legend' alt='코스닥'> <a id="companysum" href="#companysum" onclick="companysummary_open('46975'); return false;" title='아이비젼웍스'> 아이비젼웍스</a> </td>
# 				<td class="textOverflow" title="특수 목적용 기계 제조업">특수 목적용 기계 제조업</td>
# 				<td class="textOverflow" title="이차전지 검사시스템 및 검사시스템 설치셋업용역">이차전지 검사시스템 및 검사시스템 설치셋업용역</td>
# 				<td class="txc">2024-09-03</td>
# 				<td class="txc">12월</td>
# 				<td class="txc" title="길기재">길기재</td>
# 				<td class="txc">
#
# 						<a href="http://www.ivw.co.kr/kor/main/" class="btn ico homepage" target="_blank" title="http://www.ivw.co.kr/kor/main/"><span>홈페이지 보기</span></a>
#
# 				</td>
# 				<td class="txc">대전광역시</td>
# 			</tr>
#
# 			<tr
#
# 			>
# 				<td class="first" title="(주)아이스크림미디어"><img src='/images/common/icn_t_ko.gif' class='vmiddle legend' alt='코스닥'> <a id="companysum" href="#companysum" onclick="companysummary_open('46130'); return false;" title='아이스크림미디어'> 아이스크림미디어</a> </td>
# 				<td class="textOverflow" title="소프트웨어 개발 및 공급업">소프트웨어 개발 및 공급업</td>
# 				<td class="textOverflow" title="교육출판, 커머스, 연수">교육출판, 커머스, 연수</td>
# 				<td class="txc">2024-08-30</td>
# 				<td class="txc">12월</td>
# 				<td class="txc" title="허주환">허주환</td>
# 				<td class="txc">
#
# 						<a href="http://www.i-screammedia.com" class="btn ico homepage" target="_blank" title="http://www.i-screammedia.com"><span>홈페이지 보기</span></a>
#
# 				</td>
# 				<td class="txc">경기도</td>
# 			</tr>
#
# 			<tr
#
# 			>
# 				<td class="first" title="이엔셀(주)"><img src='/images/common/icn_t_ko.gif' class='vmiddle legend' alt='코스닥'> <a id="companysum" href="#companysum" onclick="companysummary_open('45607'); return false;" title='이엔셀'> 이엔셀</a> <img src='/images/common/icn_t_kyung.gif' class='vmiddle legend' alt='투자경고종목'/> </td>
# 				<td class="textOverflow" title="기초 의약물질 제조업">기초 의약물질 제조업</td>
# 				<td class="textOverflow" title="첨단바이오의약품 위탁개발생산(CDMO) 서비스 / 차세대 세포,유전자 치료제">첨단바이오의약품 위탁개발생산(CDMO) 서비스 / 차세대 세포,유전자 치료제</td>
# 				<td class="txc">2024-08-23</td>
# 				<td class="txc">12월</td>
# 				<td class="txc" title="장종욱">장종욱</td>
# 				<td class="txc">
#
# 						<a href="http://www.encellinc.com/" class="btn ico homepage" target="_blank" title="http://www.encellinc.com/"><span>홈페이지 보기</span></a>
#
# 				</td>
# 				<td class="txc">서울특별시</td>
# 			</tr>
#
# 			<tr
#
# 			>
# 				<td class="first" title="(주)엠83"><img src='/images/common/icn_t_ko.gif' class='vmiddle legend' alt='코스닥'> <a id="companysum" href="#companysum" onclick="companysummary_open('47608'); return false;" title='M83'> M83</a> </td>
# 				<td class="textOverflow" title="영화, 비디오물, 방송프로그램 제작 및 배급업">영화, 비디오물, 방송프로그램 제작 및 배급업</td>
# 				<td class="textOverflow" title="VFX">VFX</td>
# 				<td class="txc">2024-08-22</td>
# 				<td class="txc">12월</td>
# 				<td class="txc" title="정성진, 김호성">정성진..</td>
# 				<td class="txc">
#
# 						<a href="http://m83.co.kr" class="btn ico homepage" target="_blank" title="http://m83.co.kr"><span>홈페이지 보기</span></a>
#
# 				</td>
# 				<td class="txc">서울특별시</td>
# 			</tr>
#
# 			<tr
#
# 			>
# 				<td class="first" title="대신밸런스제18호기업인수목적(주)"><img src='/images/common/icn_t_ko.gif' class='vmiddle legend' alt='코스닥'> <a id="companysum" href="#companysum" onclick="companysummary_open('47878'); return false;" title='대신밸런스제18호스팩'> 대신밸런스제18호스팩</a> </td>
# 				<td class="textOverflow" title="금융 지원 서비스업">금융 지원 서비스업</td>
# 				<td class="textOverflow" title="금융 지원 서비스업">금융 지원 서비스업</td>
# 				<td class="txc">2024-08-22</td>
# 				<td class="txc">12월</td>
# 				<td class="txc" title="문병식">문병식</td>
# 				<td class="txc">
#
# 				</td>
# 				<td class="txc">서울특별시</td>
# 			</tr>
#
# 			<tr
#
# 			>
# 				<td class="first" title="(주)티디에스팜"><img src='/images/common/icn_t_ko.gif' class='vmiddle legend' alt='코스닥'> <a id="companysum" href="#companysum" onclick="companysummary_open('46428'); return false;" title='티디에스팜'> 티디에스팜</a> </td>
# 				<td class="textOverflow" title="의약품 제조업">의약품 제조업</td>
# 				<td class="textOverflow" title="경피약물전달시스템(습포제, 첩부제)">경피약물전달시스템(습포제, 첩부제)</td>
# 				<td class="txc">2024-08-21</td>
# 				<td class="txc">12월</td>
# 				<td class="txc" title="김철준">김철준</td>
# 				<td class="txc">
#
# 						<a href="http://www.tdspharm.com" class="btn ico homepage" target="_blank" title="http://www.tdspharm.com"><span>홈페이지 보기</span></a>
#
# 				</td>
# 				<td class="txc">경기도</td>
# 			</tr>
#
# 			<tr
#
# 			>
# 				<td class="first" title="(주)넥스트바이오메디컬"><img src='/images/common/icn_t_ko.gif' class='vmiddle legend' alt='코스닥'> <a id="companysum" href="#companysum" onclick="companysummary_open('38965'); return false;" title='넥스트바이오메디컬'> 넥스트바이오메디컬</a> </td>
# 				<td class="textOverflow" title="의료용 기기 제조업">의료용 기기 제조업</td>
# 				<td class="textOverflow" title="내시경용 지혈재, 혈관색전 미립구">내시경용 지혈재, 혈관색전 미립구</td>
# 				<td class="txc">2024-08-20</td>
# 				<td class="txc">12월</td>
# 				<td class="txc" title="이돈행">이돈행</td>
# 				<td class="txc">
#
# 						<a href="http://www.nextbiomedical.co.kr" class="btn ico homepage" target="_blank" title="http://www.nextbiomedical.co.kr"><span>홈페이지 보기</span></a>
#
# 				</td>
# 				<td class="txc">인천광역시</td>
# 			</tr>
#
# 			<tr
#
# 			>
# 				<td class="first" title="(주)케이쓰리아이"><img src='/images/common/icn_t_ko.gif' class='vmiddle legend' alt='코스닥'> <a id="companysum" href="#companysum" onclick="companysummary_open('43119'); return false;" title='케이쓰리아이'> 케이쓰리아이</a> </td>
# 				<td class="textOverflow" title="소프트웨어 개발 및 공급업">소프트웨어 개발 및 공급업</td>
# 				<td class="textOverflow" title="XR 실감형콘텐츠">XR 실감형콘텐츠</td>
# 				<td class="txc">2024-08-20</td>
# 				<td class="txc">12월</td>
# 				<td class="txc" title="이재영">이재영</td>
# 				<td class="txc">
#
# 						<a href="http://www.k3i.co.kr" class="btn ico homepage" target="_blank" title="http://www.k3i.co.kr"><span>홈페이지 보기</span></a>
#
# 				</td>
# 				<td class="txc">대전광역시</td>
# 			</tr>
#
# 			<tr
#
# 			>
# 				<td class="first" title="전진건설로봇(주)"><img src='/images/common/icn_t_yu.gif' class='vmiddle legend' alt='유가증권'> <a id="companysum" href="#companysum" onclick="companysummary_open('07990'); return false;" title='전진건설로봇'> 전진건설로봇</a> </td>
# 				<td class="textOverflow" title="특수 목적용 기계 제조업">특수 목적용 기계 제조업</td>
# 				<td class="textOverflow" title="콘크리트 펌프카">콘크리트 펌프카</td>
# 				<td class="txc">2024-08-19</td>
# 				<td class="txc">12월</td>
# 				<td class="txc" title="고현국">고현국</td>
# 				<td class="txc">
#
# 				</td>
# 				<td class="txc">충청북도</td>
# 			</tr>
#
# 			<tr
#
# 			>
# 				<td class="first" title="(주)유라클"><img src='/images/common/icn_t_ko.gif' class='vmiddle legend' alt='코스닥'> <a id="companysum" href="#companysum" onclick="companysummary_open('08834'); return false;" title='유라클'> 유라클</a> </td>
# 				<td class="textOverflow" title="소프트웨어 개발 및 공급업">소프트웨어 개발 및 공급업</td>
# 				<td class="textOverflow" title="모바일 앱 개발 플랫폼">모바일 앱 개발 플랫폼</td>
# 				<td class="txc">2024-08-16</td>
# 				<td class="txc">12월</td>
# 				<td class="txc" title="조준희">조준희</td>
# 				<td class="txc">
#
# 						<a href="http://www.uracle.co.kr/" class="btn ico homepage" target="_blank" title="http://www.uracle.co.kr/"><span>홈페이지 보기</span></a>
#
# 				</td>
# 				<td class="txc">서울특별시</td>
# 			</tr>
#
# 			<tr
#
# 			>
# 				<td class="first" title="교보16호기업인수목적 주식회사"><img src='/images/common/icn_t_ko.gif' class='vmiddle legend' alt='코스닥'> <a id="companysum" href="#companysum" onclick="companysummary_open('48252'); return false;" title='교보16호스팩'> 교보16호스팩</a> </td>
# 				<td class="textOverflow" title="금융 지원 서비스업">금융 지원 서비스업</td>
# 				<td class="textOverflow" title="기업인수합병">기업인수합병</td>
# 				<td class="txc">2024-08-13</td>
# 				<td class="txc">12월</td>
# 				<td class="txc" title="정시화">정시화</td>
# 				<td class="txc">
#
# 				</td>
# 				<td class="txc">서울특별시</td>
# 			</tr>
#
# 			<tr
#
# 			>
# 				<td class="first" title="뱅크웨어글로벌(주)"><img src='/images/common/icn_t_ko.gif' class='vmiddle legend' alt='코스닥'> <a id="companysum" href="#companysum" onclick="companysummary_open('19948'); return false;" title='뱅크웨어글로벌'> 뱅크웨어글로벌</a> </td>
# 				<td class="textOverflow" title="소프트웨어 개발 및 공급업">소프트웨어 개발 및 공급업</td>
# 				<td class="textOverflow" title="국내외 은행 및 금융기업 대상 코어뱅킹 소프트웨어">국내외 은행 및 금융기업 대상 코어뱅킹 소프트웨어</td>
# 				<td class="txc">2024-08-12</td>
# 				<td class="txc">12월</td>
# 				<td class="txc" title="이경조, 이은중">이경조..</td>
# 				<td class="txc">
#
# 						<a href="http://bankwareglobal.com" class="btn ico homepage" target="_blank" title="http://bankwareglobal.com"><span>홈페이지 보기</span></a>
#
# 				</td>
# 				<td class="txc">서울특별시</td>
# 			</tr>
#
# 			<tr
#
# 			>
# 				<td class="first" title="아이빔테크놀로지(주)"><img src='/images/common/icn_t_ko.gif' class='vmiddle legend' alt='코스닥'> <a id="companysum" href="#companysum" onclick="companysummary_open('46047'); return false;" title='아이빔테크놀로지'> 아이빔테크놀로지</a> </td>
# 				<td class="textOverflow" title="사진장비 및 광학기기 제조업">사진장비 및 광학기기 제조업</td>
# 				<td class="textOverflow" title="생체현미경, CRO 서비스">생체현미경, CRO 서비스</td>
# 				<td class="txc">2024-08-06</td>
# 				<td class="txc">12월</td>
# 				<td class="txc" title="김필한">김필한</td>
# 				<td class="txc">
#
# 						<a href="http://www.ivimtech.com" class="btn ico homepage" target="_blank" title="http://www.ivimtech.com"><span>홈페이지 보기</span></a>
#
# 				</td>
# 				<td class="txc">대전광역시</td>
# 			</tr>
#
# 			<tr
#
# 			>
# 				<td class="first" title="(주)피앤에스미캐닉스"><img src='/images/common/icn_t_ko.gif' class='vmiddle legend' alt='코스닥'> <a id="companysum" href="#companysum" onclick="companysummary_open('46094'); return false;" title='피앤에스미캐닉스'> 피앤에스미캐닉스</a> </td>
# 				<td class="textOverflow" title="의료용 기기 제조업">의료용 기기 제조업</td>
# 				<td class="textOverflow" title="보행재활로봇 시스템">보행재활로봇 시스템</td>
# 				<td class="txc">2024-07-31</td>
# 				<td class="txc">12월</td>
# 				<td class="txc" title="박광훈">박광훈</td>
# 				<td class="txc">
#
# 						<a href="http://walkbot.co.kr" class="btn ico homepage" target="_blank" title="http://walkbot.co.kr"><span>홈페이지 보기</span></a>
#
# 				</td>
# 				<td class="txc">서울특별시</td>
# 			</tr>
#
#
#
#
# 		</tbody>
# 	</table>
# </section>
#
# <!-- 페이징 START -->
# <section class="paging-group">
# 	<div class='paging type-00'><a href='#prevPage10' class='pprev' onclick='return false;'><span>이전10개 페이지</span></a><a href='#prevPage' class='prev' onclick='return false;'><span>이전 페이지</span></a>
# <a href='#page_link_1' class='active' onclick='return false;'>1</a><a href='#page_link_2' onclick="fnPageGo('2');return false;">2</a><a href='#page_link_3' onclick="fnPageGo('3');return false;">3</a><a href='#page_link_4' onclick="fnPageGo('4');return false;">4</a><a href='#page_link_5' onclick="fnPageGo('5');return false;">5</a><a href='#page_link_6' onclick="fnPageGo('6');return false;">6</a><a href='#page_link_7' onclick="fnPageGo('7');return false;">7</a><a href='#page_link_8' onclick="fnPageGo('8');return false;">8</a><a href='#page_link_9' onclick="fnPageGo('9');return false;">9</a><a href='#page_link_10' onclick="fnPageGo('10');return false;">10</a>
# <a href='#nextPage' class='next' onclick="fnPageGo('2');return false;"><span>다음 페이지</span></a><a href='#nextPage10' class='nnext' onclick="fnPageGo('11');return false;"><span>다음10개 페이지</span></a></div><div class="info type-00">
# 전체 <em>2,716</em>건 : <strong>1</strong>/182&nbsp;&nbsp;&nbsp;
# <select id='currentPageSize' name='currentPageSize'>
# <option value='15'  selected='selected'>15건</option>
# <option value='30'  >30건</option>
# <option value='50'  >50건</option>
# <option value='100' >100건</option>
# </select>&nbsp;&nbsp;<a href='#' onclick="fnSearch1();return false;" class='btn-sprite btn-go vmiddle' title='GO'><span>GO</span></a>
# </div>
# </section>
# <!-- 페이징 END -->
#
# <script type="text/JavaScript">
# $(document).ready(function(){
# 	fn_InitTitle("회사명,업종,주요제품,상장일,결산월,대표자명,홈페이지,지역", "true,false,false,true,false,false,false,false");
# });
# </script>

# %% [markdown]
# 1. 증권종류
# 2. 회사명
# 3. 종목코드
# 4. 업종
# 5. 주요제품
# 6. 상장일
# 7. 결산월
# 8. 대표자명s
# 9. 홈페이지
# 10. 지역

# %%
page = 1
page_size = 100
final_result_df = pd.DataFrame()
while True:
    url = "https://kind.krx.co.kr/corpgeneral/corpList.do"
    payload = dict(method='searchCorpList',pageIndex=page, currentPageSize=page_size,orderMode=3,orderStat='D',searchType=13, fiscalYearEnd='all', location='all')
    r = requests.get(url, params=payload)
    print(r.status_code, end="\r")
    soup = bs(r.text, 'lxml')
    total_items = int(soup.select_one(".info.type-00 > em").text.replace(",", ""))
    total_pages = total_items // page_size + 1
    print(f"{page}/{total_pages} 수집중", end="\r")
    keys = soup.select_one("table.list.type-00.tmt30")['summary'].split(", ")  
    result = {}
    for tr in soup.select('tr'):
        for idx, (key, td) in enumerate(zip(keys, tr.select('td'))):
            if idx == 0:
                kinds = [img['alt'].strip() for img in td.select('img')]   # 1번째 증권 종류, 회사이름
                kind = ", ".join(kinds)
                code = td.select_one('a')['onclick'].split("'")[1]+"0" # 종목코드 추출
                result.setdefault('증권종류', []).append(kind) # 증권종류 저장
                result.setdefault(key, []).append(td.text)   # 회사이름 저장
                result.setdefault('종목코드', []).append(code)
            elif idx == 6:
                home_link = td.select_one('a')['href'] if td.string == None else ""  # 6번째 링크 찾기
                result.setdefault(key, []).append(home_link)
            else:
                result.setdefault(key, []).append(td.text)
    result_df = pd.DataFrame(result)
    final_result_df = pd.concat([final_result_df, result_df])
        
    if page < total_pages:
        page += 1
        time.sleep(5)
    else:
        break

display(final_result_df)
final_result_df.to_csv(f"상장기업정보{today}_기준.csv", encoding='utf-8', index=False)  # 수집일 기준으로 csv 파일로 저장
# Out:
# 28/28 수집중
#                               증권종류            회사명    종목코드  \
# 0                              코스닥    미래에셋비전스팩7호   482680
# 1                              코스닥        아이비젼웍스   469750
# 2                              코스닥      아이스크림미디어   461300
# 3                      코스닥, 투자경고종목          이엔셀    456070
# 4                              코스닥           M83   476080
# ..                             ...            ...     ...
# 11  유가증권, KTOP30, KOSPI200, KRX300       유한양행      000100
# 12          유가증권, KOSPI200, KRX300      CJ대한통운     000120
# 13                            유가증권            경방   000050
# 14                            유가증권         유수홀딩스   000700
# 15                            유가증권      한진중공업홀딩스   003480
#
#                            업종  \
# 0                  금융 지원 서비스업
# 1               특수 목적용 기계 제조업
# 2              소프트웨어 개발 및 공급업
# 3                 기초 의약물질 제조업
# 4   영화, 비디오물, 방송프로그램 제작 및 배급업
# ..                        ...
# 11                    의약품 제조업
# 12                  도로 화물 운송업
# 13                     종합 소매업
# 14        회사 본부 및 경영 컨설팅 서비스업
# 15          연료용 가스 제조 및 배관공급업
#
#                                                  주요제품         상장일  결산월   대표자명  \
# 0                                              기업인수합병  2024-09-11  12월    송우영
# 1                           이차전지 검사시스템 및 검사시스템 설치셋업용역  2024-09-03  12월    길기재
# 2                                       교육출판, 커머스, 연수  2024-08-30  12월    허주환
# 3          첨단바이오의약품 위탁개발생산(CDMO) 서비스 / 차세대 세포,유전자 치료제  2024-08-23  12월    장종욱
# 4                                                 VFX  2024-08-22  12월  정성진..
# ..                                                ...         ...  ...    ...
# 11  의약품(삐콤씨, 안티푸라민, 렉라자, 로수바미브, 코푸시럽 등), 생활용품(유한락스...  1962-11-01  12월  대표이..
# 12  Contract Logistics, 포워딩, 항만하역, 해운, 택배국제특송, SCM...  1956-07-02  12월  신영수..
# 13          섬유류(면사,면혼방사,면직물,면혼방직물,화섬사,화섬직물) 제조,도매,수출입  1956-03-03  12월  김준,..
# 14                                               지주사업  1956-03-03  12월    송영규
# 15                                               지주회사  1956-03-03  12월  조남호..
#
#                               홈페이지     지역
# 0                                   서울특별시
# 1   http://www.ivw.co.kr/kor/main/  대전광역시
# 2     http://www.i-screammedia.com    경기도
# 3        http://www.encellinc.com/  서울특별시
# 4                 http://m83.co.kr  서울특별시
# ..                             ...    ...
# 11          http://www.yuhan.co.kr  서울특별시
# 12      http://www.cjlogistics.com  서울특별시
# 13      http://www.kyungbang.co.kr  서울특별시
# 14    http://www.eusu-holdings.com  서울특별시
# 15    http://www.hhic-holdings.com    경기도
#
# [2716 rows x 10 columns]

# %% [markdown]
# db="mysql"
# dbtype="pymysql"
# id="root"
# pw="1234"
# host="127.0.0.1:3306"
# database="korea_stock_info"

# %%
# MySQL 서버에 연결 (데이터베이스를 지정하지 않고 접속)

db="mysql"
dbtype="pymysql"
id="root"
pw="1234"
host="127.0.0.1:3306"
database="korean_stock"

# %%
# SQLAlchemy 엔진 생성
engine = create_engine(f"{db}+{dbtype}://{id}:{pw}@{host}")
# 일단 먼저 연결을 시킨다. 
conn = engine.connect()

# 데이터베이스에 지정한 데이터베이스 이름 생성
conn.execute(text("CREATE DATABASE IF NOT EXISTS korean_stock"))
# 데이터베이스가 없으면 데이터베이스를 만든다. 

engine = create_engine(f"{db}+{dbtype}://{id}:{pw}@{host}/{database}")


# DataFrame을 MySQL 테이블로 저장

conn = engine.connect()
final_result_df.to_sql('company_info', con=conn, if_exists='replace', index=False)
conn.close()

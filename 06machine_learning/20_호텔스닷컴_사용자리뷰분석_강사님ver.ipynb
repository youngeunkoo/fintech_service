# %%
import warnings
warnings.filterwarnings(action='ignore')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('https://raw.githubusercontent.com/haram4th/ablearn/main/hotel_review_75000.csv', encoding='utf-8')

# %%
data.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0  hotelId                             hotelName  \
# 0             0         356   105343  서울 웨스틴조선호텔 (The Westin Chosun Seoul)
# 1             1         357   105343  서울 웨스틴조선호텔 (The Westin Chosun Seoul)
# 2             2         358   105343  서울 웨스틴조선호텔 (The Westin Chosun Seoul)
# 3             3         359   105343  서울 웨스틴조선호텔 (The Westin Chosun Seoul)
# 4             4         360   105343  서울 웨스틴조선호텔 (The Westin Chosun Seoul)
#
#        tripType tripTypeText    reviewDate  rating  \
# 0        family     1박 가족 여행  2019년 1월 26일    10.0
# 1        family     1박 가족 여행   2019년 2월 4일    10.0
# 2         other        2박 여행   2019년 2월 2일    10.0
# 3       romance    1박 로맨틱 여행  2019년 1월 26일    10.0
# 4  with-friends    친구와 1박 여행  2019년 1월 25일    10.0
#
#                                          description  isKorNot
# 0  직원들 서비스나 마인드 완벽합니다 다만 노후된 시설과 좁은 라운지가 호텔 이름에 비...      True
# 1  웨스틴조선은 모든면에서 최고의 숙소라고 생각합니다 분위기 편의성 직원친절도까지 모두...      True
# 2  서울시내에서 호캉스를 누릴 수 있는 곳아침 뷔페가 맛있는 곳룸서비스가 좋았음요구사항...      True
# 3                                      가격에 맞게 만족했습니다      True
# 4  처음 세명으로 셋팅 되어있지 않은점 빼고는 직원들의 친절도 및 서비스는 모두 맘에 ...      True

# %%
stopwords = pd.read_csv("https://raw.githubusercontent.com/haram4th/ablearn/main/%ED%95%9C%EA%B5%AD%EC%96%B4%EB%B6%88%EC%9A%A9%EC%96%B4100.txt", header=None)
stopwords.head()
# Out:
#    0
# 0  이
# 1  있
# 2  하
# 3  것
# 4  들

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 75000 entries, 0 to 74999
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0.1  75000 non-null  int64
#  1   Unnamed: 0    75000 non-null  int64
#  2   hotelId       75000 non-null  int64
#  3   hotelName     75000 non-null  object
#  4   tripType      75000 non-null  object
#  5   tripTypeText  75000 non-null  object
#  6   reviewDate    75000 non-null  object
#  7   rating        75000 non-null  float64
#  8   description   75000 non-null  object
#  9   isKorNot      75000 non-null  bool
# dtypes: bool(1), float64(1), int64(3), object(5)
# memory usage: 5.2+ MB

# %%
len(data['description'])
# Out:
# 75000

# %%
data.columns
# Out:
# Index(['Unnamed: 0.1', 'Unnamed: 0', 'hotelId', 'hotelName', 'tripType',
#        'tripTypeText', 'reviewDate', 'rating', 'description', 'isKorNot'],
#       dtype='object')

# %%
data = data[['rating', 'description']]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 75000 entries, 0 to 74999
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   rating       75000 non-null  float64
#  1   description  75000 non-null  object
# dtypes: float64(1), object(1)
# memory usage: 1.1+ MB

# %%
data.head()
# Out:
#    rating                                        description
# 0    10.0  직원들 서비스나 마인드 완벽합니다 다만 노후된 시설과 좁은 라운지가 호텔 이름에 비...
# 1    10.0  웨스틴조선은 모든면에서 최고의 숙소라고 생각합니다 분위기 편의성 직원친절도까지 모두...
# 2    10.0  서울시내에서 호캉스를 누릴 수 있는 곳아침 뷔페가 맛있는 곳룸서비스가 좋았음요구사항...
# 3    10.0                                      가격에 맞게 만족했습니다
# 4    10.0  처음 세명으로 셋팅 되어있지 않은점 빼고는 직원들의 친절도 및 서비스는 모두 맘에 ...

# %%
data['rating'].value_counts()
# Out:
# rating
# 10.0    34103
# 8.0     24283
# 6.0      8877
# 4.0      4278
# 2.0      3459
# Name: count, dtype: int64

# %%
sns.histplot(data['rating'])
# Out:
# <Axes: xlabel='rating', ylabel='Count'>

# %%
for i in list(data.loc[data['rating'] == 6, 'description'])[10:30]:
    print(i)
    print()
# Out:
# 투숙객 많아서 발렛도 안됐고 엘베수리까지 하는 통에 타고 내리는데 시간이 진짜 오래 걸렸다  객실에 와인잔이나 디저트 먹을 정도의 디쉬들도 비치가 안되어있어 나이프랑 포크 접시 가져다줄수있냐고했더니 그것도 1인당 5천원씩 청구함 심지어 밤에 추웠음 난방이 중앙난방이라서 그렇다나뭐라나
#
# 코로나 영향으로 직원수는 적고 체크인에 관한 진행은 너무 불쾌하고제가 알던 하야트 맞나요 위기 속에 어떠한 대처가 더 빛을 발휘하는데이번 스테이는 프론트의 대처 미숙 및 두 번 다시 얼굴 보기 싫을 정도 였습니다
#
# 방이 꽤나 건조합니다휴대용가습기 가져갔었어요입지조건이 최상이고 호텔내 서비스는 글쎄요 짧게 스탠다드룸 묵어 더 한 서비스는 바라지도 않았지만그래도 기본서비스는 해줘야하지 않나요 조식먹을때 앉자마자 커피물어보더니 한 15분뒤에 식사랑 같이 나옴요아 물론 옆테이블에 혼자온 분은 특실에 묵는지모르겠지만 바삐움직여 커피금방주고 요거트종류별로 주고 불편한거 없는지 계속 신경쓰고넘 티나게 차별받는다는 기분 들었네요 작년에 홍콩사모에서 인수됐던데 f&b서비스강화와 투숙인 부대시설이용 가능 부분을 좀 늘리는 전략을 좀 짰음 좋겠습니다 코로나때문인지 조식뷔페가 없어지고 정찬셋팅을 하던데 맛은 좋았어요 특히 메로구이 허나 객장에서 직원들한테 야 네가 좀 해라는 큰 대화는 좀 거슬렸어요아무튼 다음에 숙박은 글쎄입니다
#
# 위치나 서비스 등은 늘 그렇듯이 최고의 호텔이지만 서울시내 다른 5성급호텔과 비교해서 시설이나 객실이 너무 낡았고 특히 객실위쪽 벽에 붙어있는 거울이 너무 불편하게 느껴졌습니다 뭔가 옆방하고 뚫려있는듯한 느낌입니다 그냥 주관적인 소견입니다
#
# 침대 매트리스가 허리가 너무 아파요
#
# 방음이 엉망입니다복도에서 신음소리가 엄청나요
#
# 깨끗하고 조용하고 친절합니다 코로나 때문인지  체육관 대여 서비스에 부재가 있습니다 충전기 절도 때문인지 충전기 대여서비스에 부재가 있습니다 수영장 치킨은 신라호텔이 양과 맛에서 더 좋았습니다
#
# 5성급인걸로 알고 있는데화장실 하수구 청소를 안해서 물이 세면대까지 넘쳤어요 어린 아이가 있어서 청결에 좀 더 신경이 쓰였는데침대 헤드위는 먼지가 가득했습니다 다신 이용하고 싶지 않았어요
#
# 음 5성급 호텔인데 우선 방과 방사이에 방음이 심하게 안되고 조치를 취하기 원해서 프론트에 연락했는데 피드백도 시원치가 않아요 두번째 전화하고 나서야 클래임이 들어갔네요조식뷔페 서비스 직원 깡패인줄 말투나 행동이 5성급을 떠나 서비스 받는 플랫폼인데 말이 안됩니다야경이 좋아서 매년 한두번씩 가는데 이번에 새로운 악질 서비스를 받고 앞으로는 서울에 널린 다른 5성급 호텔을 이용할것 같습니다
#
# 아이스링크와 수영장은 관리도 잘 되어 있고 이용하기도 편했음 하지만 객실은 지은 지 오래되어 그런지 옆방 소음이 꽤 들려 굉장히 불편 침대 프레임도 각이 져 있는데 부딪히면 부상으로 이어지는 위험한 구조 적극적인 개선이 필요해 보임
#
# 대체적으로 만족하나 수영장풀과 탈의실 거리가 너무멀어 이동간 추웠어요
#
# 연휴때긴했는데 체크인이 너무 혼잡했음 배정 방 근처 방들 계속 청소가 이어짐 무엇보다 화장실에 샤워헤드있는 부분과 변기있는 부분 구분이 안되어있어 샤워하고 나면 온통 홍수가됨
#
# good 얼리 체크인 할수있었고 수영장이 깨끗하고 선베드도 무료로 이용할수있었습니다bad 객실 청소 상태가 매주 좋지못하였습니다 여기저기 먼지투성이 세면대에는 물때가 그리고 코로나로 라운지 이용이 제한적이었는데 이점을 미리 안내받지 못하였고 해피아워 때 나온 음식은 너무 짰습니다맛도 그럭저럭 서비스도 아주 친절하다는 느낌은 받지못하였습니다 재방문은 안할것같네요
#
# 하얏트가 예전같지 않네요룸상태 실망 다른 방으로 바꿨는데 역시 소파에 더러운 얼룩이음식도 별로코로나 탓일까요하지만 오랜 추억이 있는 곳이라 아직도 설레는 곳이에요사우나는 깨끗하고 조용했어요아침식사때 너무나 아름다운 일출을 내자리에서봤어요
#
# 남산이 잘 보이고 야경이 좋습니다 방음이 잘 안되어서 좀 시끄럽네요
#
# 1 다른 호텔과 구별되는 룸의 특징이라면 침대 공간은 넓게 잡은 반면 화장실과 욕조 공간을 좁게 잡아서 이용이 다소 불편할 정도라는 점입니다 청결도는 좋았지만 룸에 거울이 너무 많이 붙어 있어서 다소 산만하고 어지러운 느낌을 줍니다 아마도 상대적으로 룸을 넓게 보이도록 효과를 주고자 한 것 같은데 처음 잠깐만 그런 인상을 주고 오래 있으면 산만합니다2 책상 하나도 없는 룸은 요즘 룸 추세와는 다소 다르네요3 주차비도 유료입니다 물론 투숙객 할인은 있지만 다소 이해가 되지 않습니다4 코로나때문이라고는 하는데 피트니스에서 운동복도 대여해 주지 않는다고 하더군요 그런 중요한 정책의 변화는 사전에 미리 공지가 되어야고객들에게 개별적으로 알려주지는 않더라도 적어도 호텔 홈페이지나 세부정책 부분에는 소개가 되어 있어야 한다고 생각합니다 마땅할텐데 아무런 사전 고지가 없어서 결국 호텔에 묵으면서 시설을 제대로 이용할 수 없었습니다 근래 계속 다른 호텔도 묵어 보았는데 코로나 때문에 운동복을 대여해주지 않는 호텔은 여기가 처음이었습니다5 원래 메뉴에 없음에도 고기를 먹지 않는 손님을 위해 신속하게 다른 준비를 제공하는 서비스마인드는 높이 살만했습니다 특급 호텔이라는 게 이런 서비스에서 차이가 나는 것이지요
#
# 객실 시설 노후되어 샤워나 세면이 불편합니다 한강 뷰나 남산에 있는 지리적 이점 말고는 딱히 다른 호텔들에비해서 장점이 없습니다
#
# 15년만에 다시간 하얏트호텔방도 딱히달라진것도없고 생활흠집이나 가구 침대들도 오래된듯한가구밑엔 먼지가워낙 직원분이들 친절하셔서 크게 컴플레인 하진않았지만 극성수기기간이라 사람도많고 음식주문함 기본30분이고15년후에 다시올께요
#
# 애기들과 2박 투숙하며 수영하고 놀았는데요 수영장시설 잔디 썬베드 모두 좋았습니다다만 성수기에 투숙객이 많아서인지 체크인 시간이 지나서도 방이 준비되어 있지 않았습니다 그리고 별 대수롭지 않다는듯 수영이라도 하면서 기다리라는 서비스들은 많이 아쉽습니다
#
# 공사중이라 너무 시끄러웠고 조식이 별로였음

# %%
for i in list(data.loc[data['rating'] == 8, 'description'])[30:60]:
    print(i)
    print()
# Out:
# 직원들이 친절합니다 라운지의 음식 종류는 좀 부족한 편입니다 객실은 청결하고 주변 관광지의 접근도 용이합니다
#
# 코로나19로 방에만 있어서  제대로 된 평가가 힘듭니다
#
# 전반적으로 만족 다만 화장실이 너무 낡았어요세면대에 물이 잘 안내려가요
#
# 객실이 건조 합니다가습기 필수엘리베이터가 너무 늦습니다4대 모두 층마다 다멈춤개선필요
#
# 저는 19층이었는데 역시 뷰맛집처럼 정말 좋았네요모든 직원분들 친절하셨고  룸서비스 식사도 좋았어요아이스링크 위치를 체크인할때 물어보지 않아서 나중에 건물전체를 돌았는데 사실은 엘리베이터타고 지하 2층에 가야만 됐던거였어요  작은거지만 체크인할때 물어보지않더라도 이야기해주셨으면 했네요 그거 빼고는 객실상태 청결도 만족스러웠습니다
#
# 직원들서비스나 위치 한강뷰 실내 수영장 다 너무좋았어요 다만 코로나때문에 조식을 4가지 중 선택해서 먹었는데 맛이아쉬었네요  해외여행도 못가는 요즘 호캉스로 그나마 기분전환했어요
#
# 코너룸 뷰와 직원분들의 친절도는 마음에 들었으나 룸 청결도는 별로였어요
#
# 만족합니다
#
# 뷰도 좋았고 청결했으며 직원들도 친절했습니다다만 옆방이 어린아이들이 딸린 가족이었는데방음은 생각보다 잘 되는것같진않아서 아쉽네요
#
# 위치와 전망 모두 아주 좋았으나 주차하는데 30분 걸렸어요 발렛도 다 차서 안된다고 해서 지하 2층에 주차하고 걸어 올라갔네요 주차비도 별도로 만원 받는데 주차 서비스 부분이 너무 아쉽네요
#
# 약간 먼지가 많은 느낌이였지만직원분들은 모두 친절하시고그날 마침 첫눈이 내려 침대에 누워 창밖으로 보는 눈이 너무 좋았습니다
#
# 욕조가 없어서 아쉽긴 했지만시설 청결도 분위기 직원분들 서비스 조식 전체적으로 다 좋았습니다
#
# 한강뷰 너무 좋았고 직원들 친절했으나 룸에 들어가서 청소가 덜되어있었고 침구는 청소되어있어서 그냥 썼는데 이전손님 침대하나 더 들어와있고 유료라고해서 가져가라고했으나 오질않았어요 주말이라 그런가 처리가 늦고 룸서비스 음식은 맛있었어요몇가지빼고는 만족
#
# 뷰가 좋아요
#
# 주차장에들어서면서 부터 너무힘들었어요 호텔주차하는데 너무오래걸려서 운전자만두고 먼저 내려서 체크인했네요  객실은깨끗했지만 욕조에 머리카락이붙어있고 바스타올은 한개만 준비되있었습니다 좀더신경써주시면 감사하겠습니다 하지만 객실에서 보이는 스케이트장조명은멋졌습니다
#
# 연말이라 체크인하는 데 좀 오래 걸렸어요 대신 기다리는 동안 하겐다즈 아이스크림 주셔서 지루하지 않게 기다렸습니다 아이스링크 쪽 뷰였는데 한강 보이고 밤에 너무 좋았고 저희 방은 엘베쪽이었는데 시끄러운 거 못 느낀 거 보면 방음도 잘 된 것 같습니다 침구도 엄청 편해서 꿀잠 잤고 아침 조식도 다 맛있었어요 근데 룸에서 컵이랑 커피머신 사용 할 때 보니까 먼지가 좀 쌓여 있더라구요 청소만 좀 더 꼼꼼히 되면 완벽할 것 같습니다
#
# 오래 되었지만 매우 만족 스런 호텔 입니다역시 하이야트
#
# 일반 스탠다드 룸 보다 비싼 코너룸 예약해서 기대 많이 하고 갔는데 3층 별관옥상뷰 남산타워가 보이긴 잘 보였지만 전망은 조금 아쉬웠어요 체크인 하실때 확인하시고 올라가시는게 좋을 것 같습니다 그 외에 방 크기는 다른 호텔보다 넓은편 같고 조식도 맛있었어요
#
# 소파베드를 신청했는데 1박당 60500원 별 거 아닌 서비스에 좀 비싸게 받는듯요 그닥 편하지도 않음 객실 다 좋은데 외풍이 심함 2중창이 아님 감기 걸릴뻔 공조가 어떤지는 모르지만  환기도 잘 안되는듯 전체적으론 서비스 괜찮은데 투숙객들이 몰릴때는 로비가 많이 붐빔 굳이 커피숍을 로비에 그렇게 크게 둘 이유가 없음 붐비는 로비 지나치게 어두운 조명 전반적으로 호텔이용에 첫 인상부터가 별로임 예전 구닥다리 방식인데 요새는 로비는 완전 개방형으로 두고 곳곳에서 숨어서 서비스하는 게 유행인데  암튼 유명한 곳이고 추억이 있는 곳이라 오랜만에 가봤는데 너무 예전 스타일을 고수하니 요새 왜 최고로 안쳐주는지 느껴짐 아 세월이여
#
# 3살아이랑 호캉스하러 갔는데 설연휴라서 사람이 너무 많아서 사람 구경하다가 왔네요
#
# 경치도 좋고 수영장도 좋았는데 방에 먼지가 나무너무너무 많아서 먼지닦으면 또 쌓이고 공기청청기  필요해요
#
# 친절하고 깨끗하고 룸서비스도 맛있었어요
#
# 전반적으로 만족했습니다 단 방음이 좀 안되는 것 같네요
#
# 전체적으로 만족합니다 기분 좋게 편안하게 잘 쉬다 왔습니다 입구에 들어갈 때 났던 향과 어메너티의 향은 좋은 기억으로 오래 남을 것 같습니다 다만 한가지 아쉬웠던 점은 카펫 때문이었는지 묵은지 하루가 채 되지 않았는데도 방안 테이블에 먼지가 수북하게 쌓이더군요 이 점은 조금 아쉬웠지만 그 외에는 대체적으로 만족하는 여행이었습니다
#
# 어린 아이 둘과 함께 저희 4인 가족 이틀 묵고 왔어요 직원분들 매우 친절하셔서 식사하면서도 수영하면서도 기분 좋게 잘 지내다 왔어요 다만 10월 초순경인데 밤에는 좀 쌀쌀해서 좀 춥게 잤네요  2425도 온도를 유지해주신대요  그리고 침대 가드가 없어서 아이들이 자면서 한번씩 굴러 떨어지는 일이 있었어요 다치진 않았지만 첫날은 불안해서 잘수가 없더군요
#
# 코로나때문에자유로운 조식이 아니어서 아쉬웠어요나머지는 직원분들이 최대한 맞춰주시려고노력하신것같아요한식에 쌀밥이 아쉬웠어요쌀 좋은걸로써주세요
#
# 경치 좋음직원 교육은 부족한 듯
#
# 좋아요
#
# 직원분들이 친절해서 좋았으나 욕실 청결상태가 너무 안좋네요 머리카락도 많이 있고 물 때도 보여서 욕조 사용을 못했습니다 신경 써 주시기 바랍니다
#
# 역시 하얏트는 항상 좋네요

# %%
data['isgood'] = data['rating'].apply(lambda x: 1 if x >= 8 else 0)

# %%
data
# Out:
#        rating                                        description  isgood
# 0        10.0  직원들 서비스나 마인드 완벽합니다 다만 노후된 시설과 좁은 라운지가 호텔 이름에 비...       1
# 1        10.0  웨스틴조선은 모든면에서 최고의 숙소라고 생각합니다 분위기 편의성 직원친절도까지 모두...       1
# 2        10.0  서울시내에서 호캉스를 누릴 수 있는 곳아침 뷔페가 맛있는 곳룸서비스가 좋았음요구사항...       1
# 3        10.0                                      가격에 맞게 만족했습니다       1
# 4        10.0  처음 세명으로 셋팅 되어있지 않은점 빼고는 직원들의 친절도 및 서비스는 모두 맘에 ...       1
# ...       ...                                                ...     ...
# 74995    10.0  조식과 스탠더드 하프전망 신청해서  1박 했는데요ᆢ너무 좋아요ᆢ다만 가격이 좀 나가...       1
# 74996     8.0  객실은 깔끔하고 에메니티도 딱 필요한만큼 있었습니다 5분거리에 중앙시장이 있어 쇼핑...       1
# 74997     8.0  배드가 좋고 조용해서 좋았습니다찬바람이 좀 들어와서 난방기를 12시간 정도 돌려야 ...       1
# 74998     8.0  우선 위치가 너무 좋았고 숙소에 짐을 놓고 걸어서 주변 가볼곳도 있고 먹거리도 맛있...       1
# 74999     6.0  주차장이 부족해서 다른데에 주차했는데 아침에 이동해달라는 전화가 와서 다소 불쾌했슴...       0
#
# [75000 rows x 3 columns]

# %%
from konlpy.tag import Mecab
mecab = Mecab()

# %%
data['description2'] = data['description'].apply(lambda x: mecab.nouns(x))

# %%
data
# Out:
#        rating                                        description  isgood  \
# 0        10.0  직원들 서비스나 마인드 완벽합니다 다만 노후된 시설과 좁은 라운지가 호텔 이름에 비...       1
# 1        10.0  웨스틴조선은 모든면에서 최고의 숙소라고 생각합니다 분위기 편의성 직원친절도까지 모두...       1
# 2        10.0  서울시내에서 호캉스를 누릴 수 있는 곳아침 뷔페가 맛있는 곳룸서비스가 좋았음요구사항...       1
# 3        10.0                                      가격에 맞게 만족했습니다       1
# 4        10.0  처음 세명으로 셋팅 되어있지 않은점 빼고는 직원들의 친절도 및 서비스는 모두 맘에 ...       1
# ...       ...                                                ...     ...
# 74995    10.0  조식과 스탠더드 하프전망 신청해서  1박 했는데요ᆢ너무 좋아요ᆢ다만 가격이 좀 나가...       1
# 74996     8.0  객실은 깔끔하고 에메니티도 딱 필요한만큼 있었습니다 5분거리에 중앙시장이 있어 쇼핑...       1
# 74997     8.0  배드가 좋고 조용해서 좋았습니다찬바람이 좀 들어와서 난방기를 12시간 정도 돌려야 ...       1
# 74998     8.0  우선 위치가 너무 좋았고 숙소에 짐을 놓고 걸어서 주변 가볼곳도 있고 먹거리도 맛있...       1
# 74999     6.0  주차장이 부족해서 다른데에 주차했는데 아침에 이동해달라는 전화가 와서 다소 불쾌했슴...       0
#
#                                             description2
# 0            [직원, 서비스, 마인드, 완벽, 노후, 시설, 라운지, 호텔, 이름, 부족]
# 1          [웨스틴, 조선, 면, 최고, 숙소, 생각, 분위기, 편의, 직원, 친절, 인상]
# 2      [서울, 시내, 호, 수, 곳, 아침, 뷔페, 곳, 룸서비스, 요구, 사항, 응대,...
# 3                                               [가격, 만족]
# 4      [처음, 명, 셋, 점, 직원, 친절, 서비스, 맘, 시설, 불편, 추가, 커피, ...
# ...                                                  ...
# 74995  [조식, 스탠더드, 하프, 전망, 신청, 박, 가격, 앞, 건물, 전망, 차, 가격...
# 74996            [객실, 에메, 니티, 필요, 만큼, 분, 거리, 중앙, 시장, 쇼핑]
# 74997                             [배드, 찬바람, 난방기, 시간, 정도]
# 74998              [위치, 숙소, 짐, 주변, 곳, 먹거리, 곳, 바다, 전망, 굿]
# 74999           [주차장, 부족, 데, 주차, 아침, 이동, 전화, 주차, 관리, 신경]
#
# [75000 rows x 4 columns]

# %%
stopwords = list(stopwords[0])
stopwords
# Out:
# ['이',
#  '있',
#  '하',
#  '것',
#  '들',
#  '그',
#  '되',
#  '수',
#  '왜',
#  '뭐',
#  '거',
#  '해',
#  '저',
#  '너',
#  '건',
#  '은',
#  '걸',
#  '진짜',
#  '보',
#  '않',
#  '없',
#  '나',
#  '사람',
#  '주',
#  '아니',
#  '등',
#  '같',
#  '우리',
#  '때',
#  '년',
#  '가',
#  '한',
#  '지',
#  '대하',
#  '오',
#  '말',
#  '일',
#  '그렇',
#  '위하',
#  '때문',
#  '그것',
#  '두',
#  '말하',
#  '알',
#  '그러나',
#  '받',
#  '못하',
#  '일',
#  '그런',
#  '또',
#  '문제',
#  '더',
#  '사회',
#  '많',
#  '그리고',
#  '좋',
#  '크',
#  '따르',
#  '중',
#  '나오',
#  '가지',
#  '씨',
#  '시키',
#  '만들',
#  '지금',
#  '생각하',
#  '그러',
#  '속',
#  '하나',
#  '집',
#  '살',
#  '모르',
#  '적',
#  '월',
#  '데',
#  '자신',
#  '안',
#  '어떤',
#  '내',
#  '내',
#  '경우',
#  '명',
#  '생각',
#  '시간',
#  '그녀',
#  '다시',
#  '이런',
#  '앞',
#  '보이',
#  '번',
#  '나',
#  '다른',
#  '어떻',
#  '여자',
#  '개',
#  '전',
#  '들',
#  '사실',
#  '이렇',
#  '점',
#  '싶',
#  '말',
#  '정도',
#  '좀',
#  '원',
#  '잘',
#  '통하',
#  '소리',
#  '놓']

# %%
stopwords.extend(['들', '나', '된', '과', '은', '가', '에', '호텔', '것', '수'])

# 단어 추가하기

# %%
stopwords
# Out:
# ['이',
#  '있',
#  '하',
#  '것',
#  '들',
#  '그',
#  '되',
#  '수',
#  '왜',
#  '뭐',
#  '거',
#  '해',
#  '저',
#  '너',
#  '건',
#  '은',
#  '걸',
#  '진짜',
#  '보',
#  '않',
#  '없',
#  '나',
#  '사람',
#  '주',
#  '아니',
#  '등',
#  '같',
#  '우리',
#  '때',
#  '년',
#  '가',
#  '한',
#  '지',
#  '대하',
#  '오',
#  '말',
#  '일',
#  '그렇',
#  '위하',
#  '때문',
#  '그것',
#  '두',
#  '말하',
#  '알',
#  '그러나',
#  '받',
#  '못하',
#  '일',
#  '그런',
#  '또',
#  '문제',
#  '더',
#  '사회',
#  '많',
#  '그리고',
#  '좋',
#  '크',
#  '따르',
#  '중',
#  '나오',
#  '가지',
#  '씨',
#  '시키',
#  '만들',
#  '지금',
#  '생각하',
#  '그러',
#  '속',
#  '하나',
#  '집',
#  '살',
#  '모르',
#  '적',
#  '월',
#  '데',
#  '자신',
#  '안',
#  '어떤',
#  '내',
#  '내',
#  '경우',
#  '명',
#  '생각',
#  '시간',
#  '그녀',
#  '다시',
#  '이런',
#  '앞',
#  '보이',
#  '번',
#  '나',
#  '다른',
#  '어떻',
#  '여자',
#  '개',
#  '전',
#  '들',
#  '사실',
#  '이렇',
#  '점',
#  '싶',
#  '말',
#  '정도',
#  '좀',
#  '원',
#  '잘',
#  '통하',
#  '소리',
#  '놓',
#  '들',
#  '나',
#  '된',
#  '과',
#  '은',
#  '가',
#  '에',
#  '호텔',
#  '것',
#  '수']

# %%
print(stopwords)
print()
print(type(stopwords))
# Out:
# ['이', '있', '하', '것', '들', '그', '되', '수', '왜', '뭐', '거', '해', '저', '너', '건', '은', '걸', '진짜', '보', '않', '없', '나', '사람', '주', '아니', '등', '같', '우리', '때', '년', '가', '한', '지', '대하', '오', '말', '일', '그렇', '위하', '때문', '그것', '두', '말하', '알', '그러나', '받', '못하', '일', '그런', '또', '문제', '더', '사회', '많', '그리고', '좋', '크', '따르', '중', '나오', '가지', '씨', '시키', '만들', '지금', '생각하', '그러', '속', '하나', '집', '살', '모르', '적', '월', '데', '자신', '안', '어떤', '내', '내', '경우', '명', '생각', '시간', '그녀', '다시', '이런', '앞', '보이', '번', '나', '다른', '어떻', '여자', '개', '전', '들', '사실', '이렇', '점', '싶', '말', '정도', '좀', '원', '잘', '통하', '소리', '놓', '들', '나', '된', '과', '은', '가', '에', '호텔', '것', '수']
#
# <class 'list'>

# %% [markdown]
# # 단어 빈도분석

# %%
word_dist = []
for i in data['description2']:
    for j in i:
        if j not in stopwords:
            word_dist.append(j)
    

print(len(word_dist))
# Out:
# 848852

# %%
from nltk.probability import FreqDist
import koreanize_matplotlib

# %%
FreqDist(word_dist)
# Out:
# FreqDist({'방': 13963, '친절': 13472, '만족': 13058, '시설': 11505, '직원': 11089, '조식': 11004, '이용': 10289, '위치': 9001, '객실': 8717, '주변': 8010, ...})

# %%
plt.figure(figsize=(20,10))
FreqDist(word_dist).plot(50)
# Out:
# <Axes: xlabel='Samples', ylabel='Counts'>

# %%
from wordcloud import WordCloud

# %%
font_path = "/usr/share/fonts/truetype/nanum/NanumGothic.ttf"

# %%
plt.figure(figsize=(10,5))
wc = WordCloud(font_path=font_path).generate(str(word_dist))
plt.imshow(wc)
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(399.5), np.float64(199.5), np.float64(-0.5))

# %% [markdown]
# # 만족한 고객 vs 불만족 고객

# %%
good = data[data['isgood'] == 1]['description2']
good
# Out:
# 0              [직원, 서비스, 마인드, 완벽, 노후, 시설, 라운지, 호텔, 이름, 부족]
# 1            [웨스틴, 조선, 면, 최고, 숙소, 생각, 분위기, 편의, 직원, 친절, 인상]
# 2        [서울, 시내, 호, 수, 곳, 아침, 뷔페, 곳, 룸서비스, 요구, 사항, 응대,...
# 3                                                 [가격, 만족]
# 4        [처음, 명, 셋, 점, 직원, 친절, 서비스, 맘, 시설, 불편, 추가, 커피, ...
#                                ...
# 74994                                                   []
# 74995    [조식, 스탠더드, 하프, 전망, 신청, 박, 가격, 앞, 건물, 전망, 차, 가격...
# 74996              [객실, 에메, 니티, 필요, 만큼, 분, 거리, 중앙, 시장, 쇼핑]
# 74997                               [배드, 찬바람, 난방기, 시간, 정도]
# 74998                [위치, 숙소, 짐, 주변, 곳, 먹거리, 곳, 바다, 전망, 굿]
# Name: description2, Length: 58386, dtype: object

# %%
bad = data[data['isgood'] == 0]['description2']
bad
# Out:
# 15       [가성, 별로, 기대, 실망, 예약, 사전, 메일, 직원, 통화, 객실, 요청, 고...
# 30       [번, 호텔, 방문, 것, 예전, 호텔, 이번, 실망, 주변, 호텔, 앞, 시위, ...
# 35                                       [서비스, 절도, 프로, 느낌]
# 41       [보통, 뷰, 처음, 국내외, 특급, 호텔, 곳, 중, 최악, 당일, 예약, 데이터...
# 43       [고객, 개, 법, 호텔, 역사, 명불허전, 종업원, 모두, 최상, 서비스, 무엇,...
#                                ...
# 74979    [송풍기, 환풍기, 소음, 난방, 공조, 시스템, 작동, 때, 모텔, 차이, 최근,...
# 74982                                       [비지니스, 호텔, 느낌]
# 74990    [방, 생각, 수기, 박, 만, 원, 숙소, 조리, 시설, 냉장고, 냉장고, 기능,...
# 74992    [수건, 비치, 수건, 건, 청소, 상태, 확인, 듯, 주차, 구역, 편의, 시설,...
# 74999             [주차장, 부족, 데, 주차, 아침, 이동, 전화, 주차, 관리, 신경]
# Name: description2, Length: 16614, dtype: object

# %%
plt.figure(figsize=(10,5))
wc = WordCloud(font_path=font_path).generate(str(good))
plt.imshow(wc)
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(399.5), np.float64(199.5), np.float64(-0.5))

# %%
plt.figure(figsize=(10,5))
wc = WordCloud(font_path=font_path).generate(str(bad))
plt.imshow(wc)
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(399.5), np.float64(199.5), np.float64(-0.5))

# %%
data.loc[(data['description'].str.contains("수건")) & (data['isgood'] ==0), 'description']
# Out:
# 414      수영장 이용이 횟수가 정해져있구  성수기라 만실라며 청소 상태 수건상태 엉망이구조용...
# 877      이곳에서 숙박시 가습기와 공기청정기는 필수입니다너무 건조하고 객실 공기가 좋지 못하...
# 1205     광화문광장에서 집회가 있어서 매우 혼잡하고 시끄러웠다수건 냄새피죤잡냄새 안나서 좋았...
# 1243     시설이 낡은 것을 감안하고 들어갔는데 욕실 배수가 제대로 되지 않아 불편했어요그리고...
# 1288                               수건에서 알수없는 냄새가 많이납니다쉰내아님
#                                ...
# 74615    가격대비 무난했습니다 같이 온 동료를 커플인줄 알고 스위트로 업그레이드 해주셨습니다...
# 74722    말이 호텔이니 프론트 보면 모텔 같구요환풍기가 고장인지 화장실에서 하루 종일 담배냄...
# 74788    202호 객실 사용한 사람입니다³일단 문 열고 들어서는 순간 쾌쾌란 냄새가 나고 내...
# 74792    바닥이랑 침구가 너무 눅눅하고 더러웠어요 수건에서도 물내났어요이불 덮으면 너무 꿉꿉...
# 74992    우선수건이 비치가 안되어있음수건이 없다는건 청소상태를 확인 안한듯주차구역이  적음 ...
# Name: description, Length: 670, dtype: object

# %%
for i in data.loc[(data['description'].str.contains("냉장고")) & (data['isgood'] ==0), 'description'][:50]:
    print(i)
    print()
# Out:
# 호텔시설 노후화심함특히 화장실 변기 낡았고변기 물안내려가서 변기 뚜껑열고 고리 잡아올려서 물내림침대및 내부시설 노후됨투숙객한테 주차요금 징수하다니어이상실  냉장고 열고 생수잘못마신덕에  11000원 날림 조식수준 미달
#
# 5성급이라고하기엔 시설이 좀 난방 조절이 잘 안되었고 5층인데도 화장실 수압이 낮고수영장도 너무 작고냉장고도  하지만 직원들은 모두 친절했습니다호텔자체 시설면에서  그냥 무난했어요
#
# 객실에 비치된 유리컵에 무언가 갈색 찌꺼기가 그대로 남아 있는 걸 컵을 사용하고 나서야 봐서 굉장히 기분이 좋지 않았습니다 침대 베드 근처 콘센트는 금고 뒤에 있는데 커버가 벗겨져 배선이 노출되어 있기 때문에 폰 충전기 등에 사용하기 매우 좋지 않습니다 냉장고에 넣어둔 물은 얼어 있더군요 그 외에도 수전의 코팅이 벗겨져 있다거나 욕조에 머리카락이 있다거나 클로젯에 이전 숙박객의 짐이 그대로 있다거나 하는 여러가지 문제가 있었기 때문에 다시는 이용하지 않을 것 같습니다 다만 위치는 괜찮았네요
#
# 옆방 대화소리 심지어 카톡 알림음까지 들릴 정도로 방음 환경 열악함거기에 냉장고 돌아가는 소리 수도관 소리까지 추가되어 잘 수가 없었음
#
# 오래된 패브릭 소파가 너무 더럽네요 전날 냉장고에 넣어둔 맥주는 없어지고  카운트에 이야기를 전하니 우리 여사님은 그럴일 할리 없다는데 우선적으로 사과부타 해야 정상이지 가격과 위치는 좋아요
#
# 체크인 시간 맞추어 갔으나 준비되어있지 않았고 방 갯수도 잘못되어 있었음한참 기다려서 하나의 방이 준비되고또 한참 기다려서 나머지 방이 준비됨냉장고에 전 투숙객이 놓고간 음식이 남아있었음데스크 직원의 잘못은 아니지만 대처가 매우 미숙했고 미안한 모습을 찾아볼 수 없었음
#
# 일회용품칫솔 빗 등이 없는 점을 보다 보기 쉽게 표시했으면 합니다 그리고 전반적으로 오래되었고 냉장고 안이나 컵 샤워 커튼 등이 깨끗이 닦이지 않은 부분들이 조금 보였습니다 방에 베개가 쿠션감이 좋지 않았고 방 온도조절은 되지 않아 무척 건조한 밤을 보냈습니다
#
# 전반적으로 가격대비 넓은 공간 활용이 가능하고 무엇보다 레지던스형이라 요리 등이 가능한 점이 좋았습니다 하지만 물에서 특유의 비린내가 너무 심하게 났고 냉장고 등에서 냄새가 심했습니다 베개나 시트 등에서도 냄새가 났고요 이곳에서는 환경보호의 일환으로 일회용 칫솔을 제공하고 있지 않으니 참고하셔서 칫솔과 치약 챙기시고요
#
# 비싼 가격이었지만 앱을 통해 구매하면 대체로 뷰나 여타 여건이 안좋았어요 여기도 뷰를 기대했지만 바로 옆건물 사무실이 너무 코앞이라 커튼도 못걷었어요 전체적으로 낙후된 시설성애낀 냉장고 까만 욕조 배수구 등로 기대이하였어요
#
# 겉모습이나 위치에 현혹되지 마시고 서대문 근방에 숙박할 거면 몇만원 더 보태서 차라리 ㅅㄹㅅㅌㅇ를 가시길호텔 직원 교육이 안되있음다른 호실 그것도 사람 있는 호실의 키를 실수로 갖다줌 나 범죄자 만들을려고애완견 호실 옆방을 안내해줌뷰 최악 저층에 빌딩 뒷골목 주차장 보이는 뷰가 보임화장실 최악 원룸 화장실 보는줄 알았음 해바라기도 없고 “세면도구가 없었음” 클레임 걸으니 깜빡했단 식으로 죄송하다며 세면도구 가져다 줌근처에 먹을거라곤 편의점 말고 없음 서울시청쪽하고도 좀 걸어서 가야되고그리고 어이없는 건 냉장고에 술이나 먹을 것도 없으면서 디파짓은 왜 걷어가는거임 결론 진짜 최악임 돈아끼지 말고 차라리 몇만원 더 주고 ㅅㄹㅅㅌㅇ를 가시오
#
# 냉장고가 공장가계돌아가는 소리처럼 커서 코드를 뽑았네요체크아웃시간도 한참남았는데 청소한다며 문열고들어와서는 ‘사람있네’ 하고 미안하단말도없이 나가버리는 무개념 호텔그돈주고 내지는 공짜로 자라고해도 다시 가고싶지않네요
#
# 냉장고를 여니 역한 비린내가 났고 안에 있는 물은 꽁꽁 얼려져 있었습니다 몇일동안 청소를 하지 않은듯 보였습니다 침구도 깨끗하지 않아 보였습니다
#
# 룸 관리상태와 청결도가 아쉬웠어요 욕실 세면대는 깨져서 곰팡이가 피고 있었고 세면대와 샤워룸에 머리카락이 안치워져 있었습니다 침대바닥을 닦지 않은 것인지 먼지로 으적으적 했고요 심지어 냉장고 콘센트도 빠져있어서 물이 미지근했어요 외부 방음도 잘 안되어서 밤새 차소리가 크게 들립니다
#
# 주차타워 지하로 내려가는  곳 낮은 차량은 차체가 긁혀서 내려가는  곳 확인이 필요합니다 냉장고옆 커피포트 보관 트레이는 앞으로 뺐을때 뒤집혀서 컵이 떨어져서 깨졌고 저울 체중계는 준비되어 있는데 불량으로 작동되지 않았습니다
#
# 주차장으로 가는 통로가 굉장히 좁아서 주의가 필요합니다 객실내 냉장고가 작동이 불가능했으며 칫솔 치약은 별도로 구매해야 합니다
#
# 1 냉장고 안에 병뚜껑 머리카락 있었음 2 방 탁자 아래 쓰레기 있음 3 알파인코스터 할인 티켓을 체크아웃할때 주는 바람에 사용하지 못했음 결제 시점이 아닌 체크인 시점에 줘야 좋은 서비스겠죠4 룸정비때 티슈 채워주지 않아 모자름 다시 콜하기엔 귀찮음 5 이불은 다 헤짐 구멍 많음 6 전기밥솥 압력으로 바꾸길 희망 너무 오래된 전기밥솥임 결론적으로 위생상태 엉망 서비스도 별로였음
#
# 예약후 방문3시 체크인인데 3시 40분쯤 도착 그런데도 만실이라 룸이 준비가 안됐다며 20분 좀 넘게 기다림  냉장고는 작동하지 않았으며 프론트에서 알려준대로 제일 강냉으로 조절해봤으나 아예 작동하지않음냉장보관해야 할게 있다면 직원을 올려보내 프론트에서 맡아준다 했으나  생수 하나 마실때에도 직원이 오르락내리락 해야하나 싶어 그냥 포기기존 이그제큐티브 라운지였고 해피아워가 진행되던 15층이 모든 투숙객에게 개방되고 대신 5층 모모카페 반쪽에서 진행되는거로 바뀜음식구성도 바뀌고 핫플레이트 위에 따뜻히 진열되고 알차게 나오던 음식구성 아님뷰역시 뷰라고 할것도 없이 형편없었음조식때 키위와 오렌지가 슬라이스도 안되고 껍질채 통으로 나옴한마디로 그 어떤 호텔 이용시에도 겪어보지 못한 일들의 연속이었으며 해당 호텔 이용 경험만 놓고보더라도 처음 겪어봄직원분들은 여전히 친절했으나 대체 호텔측에서 왜 이런 변화를 추구한건지 모르겠음재방문 의사는 현재로선 0
#
# 샤워부스 밀폐가 안되서 물이 욕실 안으로 흘러넘침 객실 냉장고 서리 및 곰팡이 자국관리 필요조식이 가격 대비 구성과 맛이 매우 훌륭함
#
# 싱크대컵에 립스틱 빨간색이 묻어있어요냉장고도 더러워요 시설이 오래됀거같지만 저렴해서 좋은데 일요일에 조식이 안되고 칫솔  치약이 없는지는 모르고 갔네요
#
# 냉장고에서 물이 새서 바닥이 흥건해저 깜짝놀랐습니다 침대보에 자국도 많고 화장실환풍구는 흡연실이랑 연결되어있는지 담배냄새가 너무 많이 들어와서 비흡연자로서 불편했고요 무엇보다 방음이 안되서 옆앞방 복도 소리가 다들리더군요 리모델링이 필요해 보입니다
#
# 주변 경관과 가든 너무 훌륭해요 스태프분들도 친절하고 그런데 룸 컨디션이 세월을 그대로 품었네요  냉장고 있는곳 곰팡이하며 커넥팅룸 소음 층간 소음정말 이렇게 모르는 이들과 한방에 지내는 듯한 느낌은 처음이네요 리모델링 해야할듯해요 동물원 동물들도 많이 신경써주시겠지만 조금 더 관리가 필요할 듯해요
#
# 일반 여관보다도 못한 호텔 청소도 불량에 냉장고에 먹다남은 음식물 하수구는 잘 내려가지도 않고 드라이 콘센트가 없어서 다음날 멀티코드 빌려서 사용 비추천 입니다
#
# 위치 정말 찾기 어렵고 주변이 인쇄공장이며 엘레베이터에서 소변 냄새 나고 8층 숙소인데 엘레베이터는 6층까지만 운행해서 짐가지고 여러번 왔다갔다 하기 힘들고 숙소 수압이 낮아 물이 졸졸 거리고 나오고 옥상을 개조 한것인지 천장 높이 무척 낮음180cm정도냉장고에 넣어둔 아이스크림이 다 녹아 컴플레인하니 2층 공용 냉장고 쓰라고 하는 직원의  센스에 할말 잃어 버리게 하는 센스손님의 컴플레인에 자기들이 할수 있는건 없다라고 하는 외국인 아르바이트생들만 있는 곳
#
# 스탠더드 더블룸을 이용한 20대 커플 남자입니다솔직히 호텔치고 제일 싼 가격이라 예약을 했는데요이용하는 내내 경악을 극치 못했습니다일단 욕조가 없는 거부터 시작해서 뭐 그거까진 그러려니 했습니다꺼지지 않고 끝없이 작동되는 에어컨쉐이빙 폼은 있으나 면도기는 없고뒤처리가 되지 않고 물이 그대로 들어있는 커피포트냉장고 속 보관일 이 얼마나 됐는지 모를법할 정도로 꽝꽝 얼어있던 음료들조식 메뉴도 무료였으니 망정이지 형편없었습니다그래서 에어컨 바람 때문에자다말고카드키를 아예 뽑고 잤습니다100일 기념으로 분위기 좀 내 볼까 싶어호텔 예약 과정에서 그나마 가격대가 저렴한 곳을 잡아이용하였으나 모텔보다 못한 시설에 너무 실망스러웠습니다54500자
#
# 방에 냉장고 고장및 벽지에 더러워 불괘함
#
# 호텔규모에 비해 실ㅐ 비품냉장고 설합장 개인세면도구 등이 비치되어 있지 않거나 사용할 수 없도록 막
#
# 체크인 도중 다른 직원에게 도움 요청하는과정에서 귀찮은듯한 표정의 남자직원시작부터 기분이 좋지 않았고객실에 들어갔을때 생수보관하는 냉장고 문이 살짝 열려 있었고  샤워가운이 1장도 없었음이용하진 않지만 욕조에 때가 있었고바닥타일틈에서 물이 스며 올라옴쇼파커버에 알수 없는 얼룩이 크게 있었음청결과는 거리가 멀단 느낌
#
# 냉장고 청소도 안되어있었고 호텔에 수건도 없어 이용하는데 불쾌했습니다전체적으로 청결하지 못한 느낌을 받았습니다
#
# 현관과의 구분이 없어서 그런지 내부 카페트 매우 더러움 슬리퍼가 있지만 먼지 굴러다녀서 너무 불쾌했음 냉장고는 왜 있는지 모르겠을 정도로 기능을 못함 매우 심각 시설팀에서 왔는데 원래 여기 호텔 냉장고 모델이 다 이렇다 정상이다 라는 당황스러운 답변을 들었음외관만 깔끔해서 속았당
#
# 오마이가쉬 미나냉장고 소리인줄 알았던 소리는 조선소에서 전달되는 웅웅거리는 저주파의 울림이라고 알게 되었고 아무리 창문을 닫고 커튼을 쳐도 뚫고 들어와 기분이 나빠져 잠을 잘수가 없어서 술을 몇잔 먹고 TV를 틀어놓고 잠을 자야했음 다음날 완전 피곤 피곤
#
# 전반적으로 4성급 호텔로는 청소상태가 불량함 욕실에 머리카락이 남아 있고 냉장고는 아예 청소가 안된 상태임 발코니는 바닥보수를 좀 해야할 상태임
#
# 패밀리 스위트룸 숙박했는데 룸 집기들이 너무 오래된 흔적들로 쇼파 오염도가 심해서 이불 깔아놓고 사용함 냉장고 내부 더러움 벽지도 뜯어져있고 리모델링이 시급함 도로앞이라 소음심함
#
# 카지노와 스키장 사이 위치는 좋음냉장고 소리 시끄러움이불에 머리카락 몇개씩 나옴
#
# 가까운곳에 있어 좋았지만 객실안 시설이 너무 노후화되었음냉장고 냉장이 안되고있는것을 밤에 알게됨
#
# 로비건 방이건 관리가 많이 안된 느낌이 들고 냉장고도 딱히 확인을 안하시는듯해요 시원하지도 않고 칸막이도 부숴지려하고
#
# 저희가 4인 가족이어서 온돌방을 신청했습니다 일단 방이 너무나도 작았습니다 미리 온돌이 켜져있었는데 방의 온도가 32도까지 올라가서 일단 온도를 꺼 놓고 미세먼지에도 불구하고 창문 열어 놓고 잤네요 온돌도 끄고 했는데도 담요가 너무 얇아서 밤새 몸도 불편하고 더워서 잠을 잘 수가 없었습니다 일단 침구가 그 어떤 싸구려 모텔보다 못했어요 정말 경악을 금치 못했습니다 어떻게 호텔이란 이름을 달고 있을지 의심스러울 정도였습니다 게다가 작은 냉장고의 소음이 너무 시끄러워서 자다말고 남편이 도저히 못 참겠다고 하면서 전원 코드 뽑아 놓고 잘 정도였어요좋은 추억을 쌓으러 여행 갔다가 숙소 때문에 이렇게 기분 나빠보기는 처음이었네요침대방은 모르겠으나 온돌방은 절대 주무시지 말라고 말씀드립니다 방은 엘레베이터 바로 건너편이었는데 자다가도 엘리베이터에서 나는 지하 2층 이소리에 깼네요
#
# 냉장고가 너무 더러움고무장갑 끼고 로비 청소하는 아줌마가 고무장갑 낀채로 로비 쇼파 정리함 복장도 모텔 청소 아줌마 복장임
#
# 청소도구방 옆 방을 배정 받앗는데  타월은 대  걸레인줄 알았다 닿고 빨아도 검으티티한 색 깔이였고 트윈 베드  침대 시트와 벼개 니 두장은 전 숙박 고객이 화장하다 흘린 화운데이션이 묻어있었다 냉장고를 열어보니 냉동실 칸에는 뽕따 아이스크림 1개가 있었다 방을 바꿔달라 말할까 하다가 그날 서울로 병원 진료온 뒤라 치료받고 피곤해 방 바꿔달란 말 못했다  새벽 1시에는 다른  숙박 손님이 방카드를 우리방 에 대고 문 열려고해 황당하고 무서웠다는
#
# 더블과 슈퍼싱글 있는데침대 뒤 공간에 베게가 넘어갔는데 먼지가 먼지가냉장고랑 옷장이랑 함께 열수 없고좁아요 욕실은 너무 넓고그닥 청결해보이지 않았네요
#
# 객실에 들어서자 음식향이 강하게 났다 이불에 립스틱자국들과 불쾌한 얼룩이 많았고 긴 머리카락들이 열가닥 넘게 나왔다 냉장고에는 꼬털인지 겨털인지 모를 털 한가닥도 있었다 객실 교환을 3번 했지만 2번째 객실에서도 립스틱자국과 곰팡이 머리카락들이 이불에 달라붙어있었다 마지막 방도 머리카락과 곰팡이가 핀 침대시트였다 화나서 그냥 내 옷을 깔고 잤다 호텔 직원이 매우 안절부절 친절하게 대해줘서 화는 못냈지만 직원 빼고 좋은 점이 없는 호텔이다 공항버스 타기 전 안씻고 누워있으려면 잡는것을 추천한다
#
# 시설이 좀 낡았고 냉장고는 청소 후 락스를 제대로 닦지 않았는지 내가 물티슈로 다시 닦은 후 사용해야했음 환기도 잘 되지 않아 공기도 탁하고 먼지 제거도 제대로 되지 않아 자면서도 불편했음
#
# 베이커리카페가 1층에 있고 작은 슈퍼도 있음프론트 직원분들은 친절했고숙박기간 차량이용도 자유로와 편리싱글침대 3개로 된 트리플룸 이용했으나침대1개는 간이침대바퀴달린라 길이가 서로 맞지않아 무성의한 느낌샤워부스 내 물때제거가 전혀 되지않아 상당히 미끄러웠으며수건상태도 좋지않음어메니티에는 칫솔치약이 없으며1회용 슬리퍼 역시 재활용 하는듯 군데군데 튿어져있어 불쾌함냉장고는 너무 작으며방음이 잘 되지않아 옆방 투숙객의 말소리가 들릴정도 재이용 의사는 없음
#
# 냉장고에서 딱따따딱 거리는 기계음이 계속들려서 밤새 뜬눈으로 보냈습니다 11시쯤 알게되어 룸을 바꿔달라고 하기도 귀찮아서 그냥 말 안했는데 엄청 후회했습니다
#
# 가족 여행이었습니다 주변이 너무 유흥지역이어서 어린아이가 있는 가족들에게는 추천하고싶지 않아요 호텔 내부는 깔끔하고 직원도 친절한 편이었습니다 로비에 드립커피를 계속 데워놓고 무료로 이용할 수 있게 해주는데 아주 만족스러웠어요 하지만 냉장고 성능이 너무 좋지 않았어요 3일이나 머물렀고 직원에게도 혹시 방을 바꿀 수 있는지 물어봤지만 아무런 응대가 없었어요 방이 매우 좁아서 옷을 걸 옷장이 매우매우 작았어요
#
# 호텔분위기는 안나요 냉장고  진짜로 작고 비데 없고 공용 슬리퍼 실을만한 공간은 아님 방이 작아요
#
# 1 옆방 떠드는소리 신경쓰임 냉장고소리 엄청 큼결론은 TV켜고 간신히 잠
#
# 시내에 있어서 가까운 이동거리가 좋으나 욕실이 너무 어두웠고 시설은 좀 낡았다는 느낌이 강하더군요 냉장고는 물이 뚝뚝 떨어지고 수건으로 받쳐두었더군요
#
# 냉장고가 고장이 나서 냉동실로만 이용함
#
# 욕조가 더럽고 방은 건조하고 냉장고는 안됩니다
#
# 가격대비 너무도 실망입니다 냉장고 고장으로 음식물이 상해서 버렸습니다청결 상태도 철저히 점섬이 필요합니다

# %% [markdown]
# # Naive Bayes를 이용한 감성분석

# %%
data.head()
# Out:
#    rating                                        description  isgood  \
# 0    10.0  직원들 서비스나 마인드 완벽합니다 다만 노후된 시설과 좁은 라운지가 호텔 이름에 비...       1
# 1    10.0  웨스틴조선은 모든면에서 최고의 숙소라고 생각합니다 분위기 편의성 직원친절도까지 모두...       1
# 2    10.0  서울시내에서 호캉스를 누릴 수 있는 곳아침 뷔페가 맛있는 곳룸서비스가 좋았음요구사항...       1
# 3    10.0                                      가격에 맞게 만족했습니다       1
# 4    10.0  처음 세명으로 셋팅 되어있지 않은점 빼고는 직원들의 친절도 및 서비스는 모두 맘에 ...       1
#
#                                         description2
# 0        [직원, 서비스, 마인드, 완벽, 노후, 시설, 라운지, 호텔, 이름, 부족]
# 1      [웨스틴, 조선, 면, 최고, 숙소, 생각, 분위기, 편의, 직원, 친절, 인상]
# 2  [서울, 시내, 호, 수, 곳, 아침, 뷔페, 곳, 룸서비스, 요구, 사항, 응대,...
# 3                                           [가격, 만족]
# 4  [처음, 명, 셋, 점, 직원, 친절, 서비스, 맘, 시설, 불편, 추가, 커피, ...

# %%
X = data['description']
y = data['isgood']

# %%
y.value_counts()
# Out:
# isgood
# 1    58386
# 0    16614
# Name: count, dtype: int64

# %%
from konlpy.tag import Mecab
mecab = Mecab()

# %%
def tokenizer(x):
    token = mecab.morphs(x)
    return token

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer

# %%
cv = CountVectorizer(tokenizer=tokenizer, max_df=0.8, min_df=4, ngram_range=(1,3), stop_words=stopwords )
X_cv = cv.fit_transform(X)

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.naive_bayes import MultinomialNB

# %%
X_train, X_valid, y_train, y_valid = train_test_split(X_cv, y, test_size=0.4, random_state=7)
X_valid, X_test, y_valid, y_test = train_test_split(X_valid, y_valid, test_size=0.5, random_state=7)

# %%
mnb = MultinomialNB()
mnb.fit(X_train, y_train)
pred = mnb.predict(X_valid)
print(classification_report(y_valid, pred))
test_pred = mnb.predict(X_test)
print("="*40, "test result", "="*40)
print(classification_report(y_test, test_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.67      0.78      0.72      3321
#            1       0.93      0.89      0.91     11679
#
#     accuracy                           0.86     15000
#    macro avg       0.80      0.83      0.81     15000
# weighted avg       0.87      0.86      0.87     15000
#
# ======================================== test result ========================================
#               precision    recall  f1-score   support
#
#            0       0.67      0.78      0.72      3308
#            1       0.93      0.89      0.91     11692
#
#     accuracy                           0.86     15000
#    macro avg       0.80      0.83      0.81     15000
# weighted avg       0.88      0.86      0.87     15000

# %% [markdown]
# # TfidfVectorizer

# %%
tfidf_cv = TfidfVectorizer(tokenizer=tokenizer, max_df=0.8, min_df=4, ngram_range=(1,3), stop_words=stopwords )
X_tfidf = tfidf_cv.fit_transform(X)

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.naive_bayes import MultinomialNB

# %%
X_train, X_valid, y_train, y_valid = train_test_split(X_tfidf, y, test_size=0.4, random_state=7)
X_valid, X_test, y_valid, y_test = train_test_split(X_valid, y_valid, test_size=0.5, random_state=7)

# %%
mnb = MultinomialNB()
mnb.fit(X_train, y_train)
pred = mnb.predict(X_valid)
print(classification_report(y_valid, pred))
test_pred = mnb.predict(X_test)
print("="*40, "test result", "="*40)
print(classification_report(y_test, test_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.33      0.48      3321
#            1       0.84      0.99      0.91     11679
#
#     accuracy                           0.84     15000
#    macro avg       0.86      0.66      0.69     15000
# weighted avg       0.85      0.84      0.81     15000
#
# ======================================== test result ========================================
#               precision    recall  f1-score   support
#
#            0       0.86      0.35      0.49      3308
#            1       0.84      0.98      0.91     11692
#
#     accuracy                           0.84     15000
#    macro avg       0.85      0.66      0.70     15000
# weighted avg       0.85      0.84      0.82     15000

# %% [markdown]
# # SMOTE 로 데이터 증폭 후 분석

# %%
# !pip install imbalanced-learn

# %%
from imblearn.over_sampling import SMOTE

# %%
y_train.value_counts()
# Out:
# isgood
# 1    35015
# 0     9985
# Name: count, dtype: int64

# %%
smt = SMOTE(random_state=7)
X_train_smt, y_train_smt = smt.fit_resample(X_train, y_train)

# %%
y_train_smt.value_counts()
# Out:
# isgood
# 1    35015
# 0    35015
# Name: count, dtype: int64

# %%
X_train_smt
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 5344475 stored elements and shape (70030, 140332)>

# %%
mnb = MultinomialNB()
mnb.fit(X_train_smt, y_train_smt)
pred = mnb.predict(X_valid)
print(classification_report(y_valid, pred))
test_pred = mnb.predict(X_test)
print("="*40, "test result", "="*40)
print(classification_report(y_test, test_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.62      0.84      0.72      3321
#            1       0.95      0.86      0.90     11679
#
#     accuracy                           0.85     15000
#    macro avg       0.79      0.85      0.81     15000
# weighted avg       0.88      0.85      0.86     15000
#
# ======================================== test result ========================================
#               precision    recall  f1-score   support
#
#            0       0.62      0.84      0.72      3308
#            1       0.95      0.86      0.90     11692
#
#     accuracy                           0.85     15000
#    macro avg       0.79      0.85      0.81     15000
# weighted avg       0.88      0.85      0.86     15000
